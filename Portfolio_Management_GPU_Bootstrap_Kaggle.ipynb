# %% [markdown]
# # MyPortfolioManagement - Complete Tutorial
#
# **Comprehensive portfolio management and optimization using Python**
#
# This notebook demonstrates all major functions in the myPortfolioManagement library.
#
# **Compatible with:** Kaggle, Google Colab
#
# **Repository:** https://github.com/ferhat00/QuantitativePortfolioManagement
#
# ---
#
# ## Table of Contents
#
# 1. [Setup & Installation](#setup)
# 2. [Data Fetching](#section1)
# 3. [Returns Calculation](#section2)
# 4. [Utility Functions](#section3)
# 5. [Portfolio Optimization](#section4)
# 6. [Performance Metrics](#section5)
# 7. [Low-Level Risk Metrics](#section6)
# 8. [Backtesting & Simulation](#section7)
# 9. [Bootstrapping](#section8)
# 10. [Clustering & Analysis](#section9)
# 11. [Visualization](#section10)
# 12. [Portfolio Selection](#section11)
# 13. [Complete Workflow](#section12)
#
# ---

# %% [markdown]
# ## <a id="setup"></a>🚀 Setup & Installation
#
# This section will:
# 1. Clone the GitHub repository
# 2. Install dependencies (optimized to avoid conflicts)
# 3. Set up the environment
# 4. Verify installation
#
# **⏱️ Estimated time:** 3-5 minutes

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
# 1. Clone and navigate
# !git clone https://github.com/msh855/QuantitativePortfolioManagement.git
# %cd QuantitativePortfolioManagement
# !git checkout fc_bootstrap_speedup
# !git pull origin fc_bootstrap_speedup
# Out:
# Cloning into 'QuantitativePortfolioManagement'...
# remote: Enumerating objects: 1954, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 1954 (delta 66), reused 54 (delta 24), pack-reused 1785 (from 3)
# Receiving objects: 100% (1954/1954), 53.51 MiB | 28.61 MiB/s, done.
# Resolving deltas: 100% (1230/1230), done.
# /kaggle/working/QuantitativePortfolioManagement
# Branch 'fc_bootstrap_speedup' set up to track remote branch 'fc_bootstrap_speedup' from 'origin'.
# Switched to a new branch 'fc_bootstrap_speedup'
# From https://github.com/msh855/QuantitativePortfolioManagement
#  * branch            fc_bootstrap_speedup -> FETCH_HEAD
# Already up to date.

# %%
# %%writefile requirements-core.txt
# pandas>=2.2.0
# numpy>=2.0.0,<2.3.0
# yfinance==0.2.58
# quandl
# finvizfinance
# yahoofinancials
# riskfolio-lib>=6.0.0
# pyportfolioopt>=1.5.5
# quantstats-lumi>=0.3.0
# empyrical-reloaded>=0.5.0
# ffn>=1.0.0
# pyfolio-reloaded>=0.9.0
# matplotlib>=3.9.0
# seaborn>=0.13.0
# plotly>=5.15.0
# scikit-learn>=1.6.0
# scipy>=1.14.0
# arch>=7.0.0
# tslearn>=0.7.0
# tsmoothie>=1.0.4
# timebudget>=0.1.0
# feature-engine>=1.9.0
# joblib>=1.5.0
# tqdm>=4.65.0
# parallel-pandas>=0.7.0
# Out:
# Overwriting requirements-core.txt

# %%
# 3. Install core packages first
# !pip install --upgrade pip
# !pip install -r requirements-core.txt
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.2 MB/s eta 0:00:0000:010:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.3
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 2)) (2.0.2)
# Collecting yfinance==0.2.58 (from -r requirements-core.txt (line 3))
#   Downloading yfinance-0.2.58-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting quandl (from -r requirements-core.txt (line 4))
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting finvizfinance (from -r requirements-core.txt (line 5))
#   Downloading finvizfinance-1.2.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting yahoofinancials (from -r requirements-core.txt (line 6))
#   Downloading yahoofinancials-1.20.tar.gz (51 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting riskfolio-lib>=6.0.0 (from -r requirements-core.txt (line 7))
#   Downloading riskfolio_lib-7.1.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (17 kB)
# Collecting pyportfolioopt>=1.5.5 (from -r requirements-core.txt (line 8))
#   Downloading pyportfolioopt-1.5.6-py3-none-any.whl.metadata (22 kB)
# Collecting quantstats-lumi>=0.3.0 (from -r requirements-core.txt (line 9))
#   Downloading quantstats_lumi-1.0.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting empyrical-reloaded>=0.5.0 (from -r requirements-core.txt (line 10))
#   Downloading empyrical_reloaded-0.5.12-py3-none-any.whl.metadata (21 kB)
# Collecting ffn>=1.0.0 (from -r requirements-core.txt (line 11))
#   Downloading ffn-1.1.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyfolio-reloaded>=0.9.0 (from -r requirements-core.txt (line 12))
#   Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 13)) (3.10.0)
# Requirement already satisfied: seaborn>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 14)) (0.13.2)
# Requirement already satisfied: plotly>=5.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 15)) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 16)) (1.6.1)
# Requirement already satisfied: scipy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 17)) (1.15.3)
# Collecting arch>=7.0.0 (from -r requirements-core.txt (line 18))
#   Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting tslearn>=0.7.0 (from -r requirements-core.txt (line 19))
#   Downloading tslearn-0.7.0-py3-none-any.whl.metadata (16 kB)
# Collecting tsmoothie>=1.0.4 (from -r requirements-core.txt (line 20))
#   Downloading tsmoothie-1.0.5-py3-none-any.whl.metadata (6.9 kB)
# Collecting timebudget>=0.1.0 (from -r requirements-core.txt (line 21))
#   Downloading timebudget-0.7.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting feature-engine>=1.9.0 (from -r requirements-core.txt (line 22))
#   Downloading feature_engine-1.9.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: joblib>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 23)) (1.5.3)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-core.txt (line 24)) (4.67.1)
# Collecting parallel-pandas>=0.7.0 (from -r requirements-core.txt (line 25))
#   Downloading parallel_pandas-0.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->-r requirements-core.txt (line 3)) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->-r requirements-core.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->-r requirements-core.txt (line 1)) (2025.3)
# Collecting inflection>=0.3.1 (from quandl->-r requirements-core.txt (line 4))
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from quandl->-r requirements-core.txt (line 4)) (1.17.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from quandl->-r requirements-core.txt (line 4)) (10.8.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from finvizfinance->-r requirements-core.txt (line 5)) (5.4.0)
# Collecting appdirs>=1.4.4 (from yahoofinancials->-r requirements-core.txt (line 6))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting scipy>=1.14.0 (from -r requirements-core.txt (line 17))
#   Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: clarabel>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (0.11.1)
# Requirement already satisfied: SCS>=3.2.7 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.2.9)
# Requirement already satisfied: cvxpy>=1.6.6 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (1.6.7)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (0.14.5)
# Collecting xlsxwriter>=3.2.2 (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7))
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: networkx>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.5)
# Requirement already satisfied: astropy>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (7.1.1)
# Requirement already satisfied: pybind11>=2.13.6 in /usr/local/lib/python3.12/dist-packages (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.0.1)
# Collecting vectorbt>=0.28.0 (from riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7))
#   Downloading vectorbt-0.28.2-py3-none-any.whl.metadata (12 kB)
# Collecting ecos<3.0.0,>=2.0.14 (from pyportfolioopt>=1.5.5->-r requirements-core.txt (line 8))
#   Downloading ecos-2.0.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.15.0->-r requirements-core.txt (line 15)) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.15.0->-r requirements-core.txt (line 15)) (25.0)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.9.0)
# Collecting ipython>=8.22.2 (from quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9))
#   Downloading ipython-9.8.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (8.4.2)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from empyrical-reloaded>=0.5.0->-r requirements-core.txt (line 10)) (1.4.2)
# Collecting peewee>=3.16.2 (from yfinance==0.2.58->-r requirements-core.txt (line 3))
#   Downloading peewee-3.17.3.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.6 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting decorator>=5.0.7 (from ffn>=1.0.0->-r requirements-core.txt (line 11))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->-r requirements-core.txt (line 13)) (3.2.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->-r requirements-core.txt (line 16)) (3.6.0)
# Requirement already satisfied: numba>=0.58.1 in /usr/local/lib/python3.12/dist-packages (from tslearn>=0.7.0->-r requirements-core.txt (line 19)) (0.60.0)
# Collecting simdkalman (from tsmoothie>=1.0.4->-r requirements-core.txt (line 20))
#   Downloading simdkalman-1.0.4-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from parallel-pandas>=0.7.0->-r requirements-core.txt (line 25)) (0.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from parallel-pandas>=0.7.0->-r requirements-core.txt (line 25)) (5.9.5)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.3->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.3->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (0.2025.10.20.0.39.8)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.3->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (6.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.58->-r requirements-core.txt (line 3)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.58->-r requirements-core.txt (line 3)) (4.15.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.11.1->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance==0.2.58->-r requirements-core.txt (line 3)) (2025.11.12)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.11.1->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (2.23)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.6.6->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (1.0.5)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (2.19.2)
# Collecting stack_data>=0.6.0 (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.8.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.58.1->tslearn>=0.7.0->-r requirements-core.txt (line 19)) (0.43.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.6.6->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.6.6->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (75.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==0.2.58->-r requirements-core.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==0.2.58->-r requirements-core.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==0.2.58->-r requirements-core.txt (line 3)) (2.6.2)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9))
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (3.0.1)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (1.0.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (8.1.5)
# Collecting dateparser (from vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7))
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (2.37.0)
# Collecting schedule (from vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7))
#   Downloading schedule-1.2.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: mypy_extensions in /usr/local/lib/python3.12/dist-packages (from vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (1.1.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.0.0->vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.0.0->vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.0.0->vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.0.15)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser->vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser->vectorbt>=0.28.0->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.6.6->riskfolio-lib>=6.0.0->-r requirements-core.txt (line 7)) (3.0.3)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->quantstats-lumi>=0.3.0->-r requirements-core.txt (line 9)) (1.6.0)
# Downloading yfinance-0.2.58-py2.py3-none-any.whl (113 kB)
# Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Downloading finvizfinance-1.2.0-py3-none-any.whl (44 kB)
# Downloading riskfolio_lib-7.1.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (308 kB)
# Downloading pyportfolioopt-1.5.6-py3-none-any.whl (62 kB)
# Downloading ecos-2.0.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
# Downloading quantstats_lumi-1.0.1-py2.py3-none-any.whl (54 kB)
# Downloading empyrical_reloaded-0.5.12-py3-none-any.whl (33 kB)
# Downloading ffn-1.1.2-py3-none-any.whl (26 kB)
# Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 27.0 MB/s  0:00:00 eta 0:00:01
# Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 75.1 MB/s  0:00:006m0:00:010:01
# Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (981 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 38.9 MB/s  0:00:00
# Downloading tslearn-0.7.0-py3-none-any.whl (372 kB)
# Downloading tsmoothie-1.0.5-py3-none-any.whl (22 kB)
# Downloading timebudget-0.7.1-py3-none-any.whl (9.5 kB)
# Downloading feature_engine-1.9.3-py3-none-any.whl (229 kB)
# Downloading parallel_pandas-0.7-py3-none-any.whl (21 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading ipython-9.8.0-py3-none-any.whl (621 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 621.4/621.4 kB 21.0 MB/s  0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading vectorbt-0.28.2-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.8/527.8 kB 12.8 MB/s  0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading schedule-1.2.2-py3-none-any.whl (12 kB)
# Downloading simdkalman-1.0.4-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: yahoofinancials, peewee
#   Building wheel for yahoofinancials (pyproject.toml) ... done
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.20-py3-none-any.whl size=38675 sha256=ff45fa5bd56ddf04689980b7b9fcb647b96dc1ce3bf8cacf8a316d4579b96fa6
#   Stored in directory: /root/.cache/pip/wheels/b0/e1/ca/e683b02e57db550881c8ebb89ba3eccb7a5c0ebfad7f03acea
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.3-py3-none-any.whl size=138487 sha256=7d25fceaecd2a3c6dbb3c78410e45c9de0bf085ee34d7e5ad4576a45a70bc950
#   Stored in directory: /root/.cache/pip/wheels/39/c7/dd/909d267742f7fbb941ff081dacd661f622a0b4eb38f667b84b
# Successfully built yahoofinancials peewee
# Installing collected packages: timebudget, pure-eval, peewee, appdirs, xlsxwriter, traitlets, simdkalman, scipy, schedule, inflection, executing, decorator, yahoofinancials, tsmoothie, stack_data, ecos, dateparser, yfinance, tslearn, quandl, parallel-pandas, ipython, finvizfinance, empyrical-reloaded, quantstats-lumi, pyportfolioopt, pyfolio-reloaded, ffn, feature-engine, arch, vectorbt, riskfolio-lib
#   Attempting uninstall: peewee
#     Found existing installation: peewee 3.18.2
#     Uninstalling peewee-3.18.2:
#       Successfully uninstalled peewee-3.18.2━━━━━━━━━━━━━━━━━━━━━━  2/32 [peewee]
#   Attempting uninstall: traitlets━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/32 [xlsxwriter]
#     Found existing installation: traitlets 5.7.1━━━━━━━━━━━━━━  4/32 [xlsxwriter]
#     Uninstalling traitlets-5.7.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/32 [xlsxwriter]
#       Successfully uninstalled traitlets-5.7.1━━━━━━━━━━━━━━━━━━━━  5/32 [traitlets]
#   Attempting uninstall: scipy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [traitlets]
#     Found existing installation: scipy 1.15.3━━━━━━━━━━━━━━━━━  5/32 [traitlets]
#     Uninstalling scipy-1.15.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [scipy]
#       Successfully uninstalled scipy-1.15.3━━━━━━━━━━━━━━━━━━━━━━━  7/32 [scipy]
#   Attempting uninstall: decorator0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [scipy]
#     Found existing installation: decorator 4.4.2━━━━━━━━━━━━━━  7/32 [scipy]
#     Uninstalling decorator-4.4.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [scipy]
#       Successfully uninstalled decorator-4.4.2━━━━━━━━━━━━━━━━━━━━ 11/32 [decorator]
#   Attempting uninstall: yfinance╺━━━━━━━━━━━━━━━━━━━ 16/32 [dateparser]
#     Found existing installation: yfinance 0.2.66━━━━━━━━━━━━━━ 16/32 [dateparser]
#     Uninstalling yfinance-0.2.66:╺━━━━━━━━━━━━━━━━━━━ 16/32 [dateparser]
#       Successfully uninstalled yfinance-0.2.660m━━━━━━━━━━━━━━━━━━ 17/32 [yfinance]
#   Attempting uninstall: ipython╸━━━━━━━━━━━━━━━━━ 18/32 [tslearn]
#     Found existing installation: ipython 7.34.0m━━━━━━━━━━━━━ 21/32 [ipython]
#     Uninstalling ipython-7.34.0:0m╺━━━━━━━━━━━━━ 21/32 [ipython]
#       Successfully uninstalled ipython-7.34.0━━━━━━━━━━━━━ 21/32 [ipython]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32/32 [riskfolio-lib]0m [riskfolio-lib]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.8.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.2.19 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed appdirs-1.4.4 arch-8.0.0 dateparser-1.2.2 decorator-5.2.1 ecos-2.0.14 empyrical-reloaded-0.5.12 executing-2.2.1 feature-engine-1.9.3 ffn-1.1.2 finvizfinance-1.2.0 inflection-0.5.1 ipython-9.8.0 parallel-pandas-0.7 peewee-3.17.3 pure-eval-0.2.3 pyfolio-reloaded-0.9.9 pyportfolioopt-1.5.6 quandl-3.7.0 quantstats-lumi-1.0.1 riskfolio-lib-7.1.0 schedule-1.2.2 scipy-1.16.3 simdkalman-1.0.4 stack_data-0.6.3 timebudget-0.7.1 traitlets-5.14.3 tslearn-0.7.0 tsmoothie-1.0.5 vectorbt-0.28.2 xlsxwriter-3.2.9 yahoofinancials-1.20 yfinance-0.2.58

# %%
# 4. Install Ray and OpenBB separately
# !pip install ray==2.53.0
# !pip install openbb==4.5.0
# Out:
# Collecting ray==2.53.0
#   Downloading ray-2.53.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (3.20.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (1.1.2)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (25.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from ray==2.53.0) (2.32.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray==2.53.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray==2.53.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray==2.53.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray==2.53.0) (0.27.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema->ray==2.53.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->ray==2.53.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->ray==2.53.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->ray==2.53.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->ray==2.53.0) (2025.11.12)
# Downloading ray-2.53.0-cp312-cp312-manylinux2014_x86_64.whl (72.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 MB 105.9 MB/s  0:00:00m0:00:0100:01
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.52.1
#     Uninstalling ray-2.52.1:
#       Successfully uninstalled ray-2.52.1
# Successfully installed ray-2.53.0
# Collecting openbb==4.5.0
#   Downloading openbb-4.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting openbb-benzinga<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_benzinga-1.5.0-py3-none-any.whl.metadata (933 bytes)
# Collecting openbb-bls<2.0.0,>=1.2.0 (from openbb==4.5.0)
#   Downloading openbb_bls-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting openbb-cftc<2.0.0,>=1.2.0 (from openbb==4.5.0)
#   Downloading openbb_cftc-1.2.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting openbb-commodity<2.0.0,>=1.4.0 (from openbb==4.5.0)
#   Downloading openbb_commodity-1.4.0-py3-none-any.whl.metadata (955 bytes)
# Collecting openbb-congress-gov<2.0.0,>=1.1.0 (from openbb==4.5.0)
#   Downloading openbb_congress_gov-1.1.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting openbb-core<2.0.0,>=1.5.1 (from openbb==4.5.0)
#   Downloading openbb_core-1.5.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting openbb-crypto<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_crypto-1.5.0-py3-none-any.whl.metadata (947 bytes)
# Collecting openbb-currency<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_currency-1.5.0-py3-none-any.whl.metadata (948 bytes)
# Collecting openbb-derivatives<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_derivatives-1.5.0-py3-none-any.whl.metadata (912 bytes)
# Collecting openbb-econdb<2.0.0,>=1.4.0 (from openbb==4.5.0)
#   Downloading openbb_econdb-1.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-economy<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_economy-1.5.0-py3-none-any.whl.metadata (953 bytes)
# Collecting openbb-equity<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_equity-1.5.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting openbb-etf<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_etf-1.5.0-py3-none-any.whl.metadata (832 bytes)
# Collecting openbb-federal-reserve<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_federal_reserve-1.5.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-fixedincome<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_fixedincome-1.5.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-fmp<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_fmp-1.5.1-py3-none-any.whl.metadata (960 bytes)
# Collecting openbb-fred<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_fred-1.5.0-py3-none-any.whl.metadata (930 bytes)
# Collecting openbb-imf<2.0.0,>=1.2.0 (from openbb==4.5.0)
#   Downloading openbb_imf-1.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting openbb-index<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_index-1.5.0-py3-none-any.whl.metadata (948 bytes)
# Collecting openbb-intrinio<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_intrinio-1.5.0-py3-none-any.whl.metadata (976 bytes)
# Collecting openbb-news<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_news-1.5.0-py3-none-any.whl.metadata (906 bytes)
# Collecting openbb-oecd<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_oecd-1.5.0-py3-none-any.whl.metadata (990 bytes)
# Collecting openbb-platform-api<2.0.0,>=1.2.1 (from openbb==4.5.0)
#   Downloading openbb_platform_api-1.2.2-py3-none-any.whl.metadata (24 kB)
# Collecting openbb-polygon<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_polygon-1.5.0-py3-none-any.whl.metadata (922 bytes)
# Collecting openbb-regulators<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_regulators-1.5.0-py3-none-any.whl.metadata (987 bytes)
# Collecting openbb-sec<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_sec-1.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting openbb-tiingo<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_tiingo-1.5.0-py3-none-any.whl.metadata (921 bytes)
# Collecting openbb-tradingeconomics<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_tradingeconomics-1.5.0-py3-none-any.whl.metadata (980 bytes)
# Collecting openbb-us-eia<2.0.0,>=1.2.0 (from openbb==4.5.0)
#   Downloading openbb_us_eia-1.2.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting openbb-yfinance<2.0.0,>=1.5.0 (from openbb==4.5.0)
#   Downloading openbb_yfinance-1.5.1-py3-none-any.whl.metadata (984 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.2 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (3.13.2)
# Collecting fastapi<0.121.0,>=0.120.3 (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0)
#   Downloading fastapi-0.120.4-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (8.7.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.3 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.12.5)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.1.1)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.32.5)
# Collecting ruff<0.14,>=0.13 (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0)
#   Downloading ruff-0.13.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting uuid7<0.2.0,>=0.1.0 (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0)
#   Downloading uuid7-0.1.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting uvicorn<0.36.0,>=0.35.0 (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.2->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.22.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<0.121.0,>=0.120.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.48.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<0.121.0,>=0.120.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi<0.121.0,>=0.120.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.5.1)
# Collecting aiohttp-client-cache<0.12.0,>=0.11.0 (from openbb-econdb<2.0.0,>=1.4.0->openbb==4.5.0)
#   Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting aiosqlite<0.21.0,>=0.20.0 (from openbb-econdb<2.0.0,>=1.4.0->openbb==4.5.0)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.4.0->openbb==4.5.0) (2.2.0)
# Collecting url-normalize<2.0,>=1.4 (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.4.0->openbb==4.5.0)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.4 in /usr/local/lib/python3.12/dist-packages (from openbb-federal-reserve<2.0.0,>=1.5.0->openbb==4.5.0) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.13.4->openbb-federal-reserve<2.0.0,>=1.5.0->openbb==4.5.0) (2.8)
# Collecting async-lru<3,>=2 (from openbb-imf<2.0.0,>=1.2.0->openbb==4.5.0)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting requests-cache<2.0.0,>=1.1.0 (from openbb-intrinio<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting defusedxml<0.9.0,>=0.8.0rc2 (from openbb-oecd<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.12/dist-packages (from openbb-oecd<2.0.0,>=1.5.0->openbb==4.5.0) (2.6.2)
# Requirement already satisfied: deepdiff>=8.6.1 in /usr/local/lib/python3.12/dist-packages (from openbb-platform-api<2.0.0,>=1.2.1->openbb==4.5.0) (8.6.1)
# Collecting inscriptis<3.0.0,>=2.5.3 (from openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading inscriptis-2.7.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (5.4.0)
# Collecting trafilatura<3.0,>=2.0 (from openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading trafilatura-2.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting xmltodict<0.14.0,>=0.13.0 (from openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from openbb-us-eia<2.0.0,>=1.2.0->openbb==4.5.0) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from openbb-us-eia<2.0.0,>=1.2.0->openbb==4.5.0) (2.0.2)
# Collecting yfinance<0.3.0,>=0.2.66 (from openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.2.0->openbb==4.5.0) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2025.11.12)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.5.0->openbb==4.5.0) (4.5.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.50.0,>=0.40.0->fastapi<0.121.0,>=0.120.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (4.12.0)
# Collecting courlan>=1.3.2 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading courlan-1.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting htmldate>=1.9.2 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading htmldate-1.9.4-py3-none-any.whl.metadata (10 kB)
# Collecting justext>=3.0.1 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading justext-3.0.2-py2.py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn<0.36.0,>=0.35.0->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<0.36.0,>=0.35.0->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (0.16.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (0.0.12)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (3.17.3)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (5.29.5)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (2.17.0)
# Collecting tld>=0.13 (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading tld-0.13.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance<0.3.0,>=0.2.66->openbb-yfinance<2.0.0,>=1.5.0->openbb==4.5.0) (2.23)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff>=8.6.1->openbb-platform-api<2.0.0,>=1.2.1->openbb==4.5.0) (5.5.0)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (2.9.0.post0)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0) (5.3.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (3.23.0)
# Collecting lxml_html_clean (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb==4.5.0)
#   Downloading lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.5.1->openbb==4.5.0) (2025.3)
# Downloading openbb-4.5.0-py3-none-any.whl (6.0 kB)
# Downloading openbb_benzinga-1.5.0-py3-none-any.whl (13 kB)
# Downloading openbb_bls-1.2.0-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 87.3 MB/s  0:00:00
# Downloading openbb_cftc-1.2.0-py3-none-any.whl (12 kB)
# Downloading openbb_commodity-1.4.0-py3-none-any.whl (3.5 kB)
# Downloading openbb_congress_gov-1.1.0-py3-none-any.whl (21 kB)
# Downloading openbb_core-1.5.6-py3-none-any.whl (292 kB)
# Downloading fastapi-0.120.4-py3-none-any.whl (108 kB)
# Downloading openbb_crypto-1.5.0-py3-none-any.whl (4.0 kB)
# Downloading openbb_currency-1.5.0-py3-none-any.whl (4.9 kB)
# Downloading openbb_derivatives-1.5.0-py3-none-any.whl (10 kB)
# Downloading openbb_econdb-1.4.0-py3-none-any.whl (97 kB)
# Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl (32 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading openbb_economy-1.5.0-py3-none-any.whl (16 kB)
# Downloading openbb_equity-1.5.0-py3-none-any.whl (16 kB)
# Downloading openbb_etf-1.5.0-py3-none-any.whl (5.3 kB)
# Downloading openbb_federal_reserve-1.5.0-py3-none-any.whl (78 kB)
# Downloading openbb_fixedincome-1.5.0-py3-none-any.whl (11 kB)
# Downloading openbb_fmp-1.5.1-py3-none-any.whl (124 kB)
# Downloading openbb_fred-1.5.0-py3-none-any.whl (105 kB)
# Downloading openbb_imf-1.2.0-py3-none-any.whl (108 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading openbb_index-1.5.0-py3-none-any.whl (4.2 kB)
# Downloading openbb_intrinio-1.5.0-py3-none-any.whl (99 kB)
# Downloading openbb_news-1.5.0-py3-none-any.whl (2.8 kB)
# Downloading openbb_oecd-1.5.0-py3-none-any.whl (30 kB)
# Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl (25 kB)
# Downloading openbb_platform_api-1.2.2-py3-none-any.whl (43 kB)
# Downloading openbb_polygon-1.5.0-py3-none-any.whl (32 kB)
# Downloading openbb_regulators-1.5.0-py3-none-any.whl (5.3 kB)
# Downloading openbb_sec-1.5.0-py3-none-any.whl (69 kB)
# Downloading inscriptis-2.7.0-py3-none-any.whl (45 kB)
# Downloading openbb_tiingo-1.5.0-py3-none-any.whl (13 kB)
# Downloading openbb_tradingeconomics-1.5.0-py3-none-any.whl (8.3 kB)
# Downloading openbb_us_eia-1.2.0-py3-none-any.whl (28 kB)
# Downloading openbb_yfinance-1.5.1-py3-none-any.whl (65 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading ruff-0.13.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 148.4 MB/s  0:00:00
# Downloading trafilatura-2.0.0-py3-none-any.whl (132 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading uuid7-0.1.0-py2.py3-none-any.whl (7.5 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
# Downloading courlan-1.3.2-py3-none-any.whl (33 kB)
# Downloading htmldate-1.9.4-py3-none-any.whl (31 kB)
# Downloading justext-3.0.2-py2.py3-none-any.whl (837 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 24.9 MB/s  0:00:00
# Downloading tld-0.13.1-py2.py3-none-any.whl (274 kB)
# Downloading lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# Installing collected packages: xmltodict, uvicorn, uuid7, url-normalize, tld, ruff, lxml_html_clean, defusedxml, cattrs, async-lru, annotated-doc, aiosqlite, requests-cache, inscriptis, courlan, yfinance, justext, htmldate, fastapi, aiohttp-client-cache, trafilatura, openbb-core, openbb-yfinance, openbb-us-eia, openbb-tradingeconomics, openbb-tiingo, openbb-sec, openbb-regulators, openbb-polygon, openbb-platform-api, openbb-oecd, openbb-news, openbb-intrinio, openbb-index, openbb-imf, openbb-fred, openbb-fmp, openbb-fixedincome, openbb-federal-reserve, openbb-etf, openbb-equity, openbb-economy, openbb-econdb, openbb-derivatives, openbb-currency, openbb-crypto, openbb-congress-gov, openbb-commodity, openbb-cftc, openbb-bls, openbb-benzinga, openbb
#   Attempting uninstall: uvicorn━━━━━━━━━━━━━━━━━  0/52 [xmltodict]
#     Found existing installation: uvicorn 0.38.0━━━━━━━━━━  1/52 [uvicorn]
#     Uninstalling uvicorn-0.38.0:━━━━━━━━━━━━━━━━━━━━━  1/52 [uvicorn]
#       Successfully uninstalled uvicorn-0.38.0━━━━━━━━  1/52 [uvicorn]
#   Attempting uninstall: ruff━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/52 [uvicorn]
#     Found existing installation: ruff 0.14.1━━━━━━━━━  1/52 [uvicorn]
#     Uninstalling ruff-0.14.1:━━━━━━━━━━━━━━━━━━━━━━━━  1/52 [uvicorn]
#       Successfully uninstalled ruff-0.14.1━━━━━━━━━━━━━━━━━━━━━━━━  5/52 [ruff]
#   Attempting uninstall: defusedxml━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/52 [ruff]
#     Found existing installation: defusedxml 0.7.1━━━━━━━━━━━━━  5/52 [ruff]
#     Uninstalling defusedxml-0.7.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/52 [ruff]
#       Successfully uninstalled defusedxml-0.7.1━━━━━━━━━━━━━━━  5/52 [ruff]
#   Attempting uninstall: aiosqlitem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/52 [annotated-doc]
#     Found existing installation: aiosqlite 0.22.0━━━━━━━━━━━━━ 10/52 [annotated-doc]
#     Uninstalling aiosqlite-0.22.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/52 [annotated-doc]
#       Successfully uninstalled aiosqlite-0.22.0━━━━━━━━━━━━━━━ 10/52 [annotated-doc]
#   Attempting uninstall: yfinance━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/52 [inscriptis]
#     Found existing installation: yfinance 0.2.58━━━━━━━━━━━━━━ 13/52 [inscriptis]
#     Uninstalling yfinance-0.2.58:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/52 [inscriptis]
#       Successfully uninstalled yfinance-0.2.58━━━━━━━━━━━━━━━━ 13/52 [inscriptis]
#   Attempting uninstall: fastapi0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/52 [yfinance]
#     Found existing installation: fastapi 0.119.1━━━━━━━━━━━━━━ 15/52 [yfinance]
#     Uninstalling fastapi-0.119.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/52 [yfinance]
#       Successfully uninstalled fastapi-0.119.1━━━━━━━━━━━━━━━━━━━━ 18/52 [fastapi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52/52 [openbb]49/52 [openbb-bls]vatives]rve]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# Successfully installed aiohttp-client-cache-0.11.1 aiosqlite-0.20.0 annotated-doc-0.0.4 async-lru-2.0.5 cattrs-25.3.0 courlan-1.3.2 defusedxml-0.8.0rc2 fastapi-0.120.4 htmldate-1.9.4 inscriptis-2.7.0 justext-3.0.2 lxml_html_clean-0.4.3 openbb-4.5.0 openbb-benzinga-1.5.0 openbb-bls-1.2.0 openbb-cftc-1.2.0 openbb-commodity-1.4.0 openbb-congress-gov-1.1.0 openbb-core-1.5.6 openbb-crypto-1.5.0 openbb-currency-1.5.0 openbb-derivatives-1.5.0 openbb-econdb-1.4.0 openbb-economy-1.5.0 openbb-equity-1.5.0 openbb-etf-1.5.0 openbb-federal-reserve-1.5.0 openbb-fixedincome-1.5.0 openbb-fmp-1.5.1 openbb-fred-1.5.0 openbb-imf-1.2.0 openbb-index-1.5.0 openbb-intrinio-1.5.0 openbb-news-1.5.0 openbb-oecd-1.5.0 openbb-platform-api-1.2.2 openbb-polygon-1.5.0 openbb-regulators-1.5.0 openbb-sec-1.5.0 openbb-tiingo-1.5.0 openbb-tradingeconomics-1.5.0 openbb-us-eia-1.2.0 openbb-yfinance-1.5.1 requests-cache-1.2.1 ruff-0.13.3 tld-0.13.1 trafilatura-2.0.0 url-normalize-1.4.3 uuid7-0.1.0 uvicorn-0.35.0 xmltodict-0.13.0 yfinance-0.2.66

# %%
# 5. Install the package
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/QuantitativePortfolioManagement
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: timebudget in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (0.7.1)
# Requirement already satisfied: quandl in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (3.7.0)
# Requirement already satisfied: feature_engine in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (1.9.3)
# Requirement already satisfied: tsmoothie in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (1.0.5)
# Requirement already satisfied: tslearn in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (0.7.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (2.0.2)
# Collecting datetime (from myPortfolioManagement==1.0)
#   Downloading datetime-6.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: quantstats-lumi in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (1.0.1)
# Requirement already satisfied: ray in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (2.53.0)
# Collecting investpy (from myPortfolioManagement==1.0)
#   Downloading investpy-1.0.8.tar.gz (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 12.0 MB/s  0:00:00eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: finvizfinance in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (1.2.0)
# Requirement already satisfied: yahoofinancials in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (1.20)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (from myPortfolioManagement==1.0) (0.2.66)
# Collecting zope.interface (from datetime->myPortfolioManagement==1.0)
#   Downloading zope_interface-8.1.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (45 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from datetime->myPortfolioManagement==1.0) (2025.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from feature_engine->myPortfolioManagement==1.0) (1.6.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from feature_engine->myPortfolioManagement==1.0) (1.16.3)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from feature_engine->myPortfolioManagement==1.0) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->myPortfolioManagement==1.0) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->myPortfolioManagement==1.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->myPortfolioManagement==1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->feature_engine->myPortfolioManagement==1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->feature_engine->myPortfolioManagement==1.0) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.11.1->feature_engine->myPortfolioManagement==1.0) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.11.1->feature_engine->myPortfolioManagement==1.0) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from finvizfinance->myPortfolioManagement==1.0) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from finvizfinance->myPortfolioManagement==1.0) (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from finvizfinance->myPortfolioManagement==1.0) (5.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->finvizfinance->myPortfolioManagement==1.0) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->finvizfinance->myPortfolioManagement==1.0) (4.15.0)
# Collecting Unidecode>=1.1.1 (from investpy->myPortfolioManagement==1.0)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.12/dist-packages (from investpy->myPortfolioManagement==1.0) (75.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->finvizfinance->myPortfolioManagement==1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->finvizfinance->myPortfolioManagement==1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->finvizfinance->myPortfolioManagement==1.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->finvizfinance->myPortfolioManagement==1.0) (2025.11.12)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from quandl->myPortfolioManagement==1.0) (0.5.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from quandl->myPortfolioManagement==1.0) (10.8.0)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi->myPortfolioManagement==1.0) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi->myPortfolioManagement==1.0) (3.10.0)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi->myPortfolioManagement==1.0) (0.9.0)
# Requirement already satisfied: ipython>=8.22.2 in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi->myPortfolioManagement==1.0) (9.8.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from quantstats-lumi->myPortfolioManagement==1.0) (8.4.2)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (5.14.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.8.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->quantstats-lumi->myPortfolioManagement==1.0) (3.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.22.2->quantstats-lumi->myPortfolioManagement==1.0) (0.2.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (4.5.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (3.17.3)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance->myPortfolioManagement==1.0) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance->myPortfolioManagement==1.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance->myPortfolioManagement==1.0) (2.23)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->quantstats-lumi->myPortfolioManagement==1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->quantstats-lumi->myPortfolioManagement==1.0) (1.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray->myPortfolioManagement==1.0) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray->myPortfolioManagement==1.0) (3.20.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray->myPortfolioManagement==1.0) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray->myPortfolioManagement==1.0) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ray->myPortfolioManagement==1.0) (6.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->myPortfolioManagement==1.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->myPortfolioManagement==1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->myPortfolioManagement==1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->myPortfolioManagement==1.0) (0.27.1)
# Requirement already satisfied: numba>=0.58.1 in /usr/local/lib/python3.12/dist-packages (from tslearn->myPortfolioManagement==1.0) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.58.1->tslearn->myPortfolioManagement==1.0) (0.43.0)
# Requirement already satisfied: simdkalman in /usr/local/lib/python3.12/dist-packages (from tsmoothie->myPortfolioManagement==1.0) (1.0.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from yahoofinancials->myPortfolioManagement==1.0) (1.4.4)
# Downloading datetime-6.0-py3-none-any.whl (52 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Downloading zope_interface-8.1.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (264 kB)
# Building wheels for collected packages: myPortfolioManagement, investpy
#   Building editable for myPortfolioManagement (pyproject.toml) ... done
#   Created wheel for myPortfolioManagement: filename=myportfoliomanagement-1.0-0.editable-py3-none-any.whl size=15647 sha256=977896149ebf90444eaaeed075e07c7c8bbd6cea2f1799c5d42ac796e97ad6b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c9ax9jwh/wheels/30/bd/d1/1723515285f61dca484ff16c26e08b96fdf9f292b91d815f54
#   Building wheel for investpy (pyproject.toml) ... done
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481672 sha256=8114015df0d64604ff6439ca9838a035055b3ea4b176374df799959d4220b732
#   Stored in directory: /root/.cache/pip/wheels/dd/f4/e0/4807b8928ec08b376e1e1f1e1cc597a747cdd8356c37ee618f
# Successfully built myPortfolioManagement investpy
# Installing collected packages: zope.interface, Unidecode, datetime, investpy, myPortfolioManagement
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [myPortfolioManagement]stpy]]
# Successfully installed Unidecode-1.4.0 datetime-6.0 investpy-1.0.8 myPortfolioManagement-1.0 zope.interface-8.1.1

# %%
# Verify installation and import all necessary libraries
import warnings
warnings.filterwarnings('ignore')

print("🔍 Verifying installation...\n")

try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    print("✅ Core libraries (pandas, numpy, matplotlib, seaborn)")
except ImportError as e:
    print(f"❌ Core libraries error: {e}")

try:
    import yfinance as yf
    import riskfolio as rp
    import quantstats_lumi as qs
    from pypfopt import EfficientFrontier
    import ffn
    print("✅ Financial libraries (yfinance, riskfolio, quantstats, pypfopt, ffn)")
except ImportError as e:
    print(f"❌ Financial libraries error: {e}")

try:
    from myPortfolioManagement.myData import get_stock_prices
    from myPortfolioManagement.myReturns import calculate_returns
    from myPortfolioManagement.myPortfolioOptimisation import HRP
    from myPortfolioManagement.myPerformanceMetrics import get_main_stats
    print("✅ myPortfolioManagement package")
except ImportError as e:
    print(f"❌ Package import error: {e}")

# Configure pandas display
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 200)
pd.set_option('display.float_format', '{:.4f}'.format)

# Configure matplotlib
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

print("\n" + "="*80)
print("🎉 SETUP COMPLETE - Ready to start!")
print("="*80)
# Out:
# 🔍 Verifying installation...
#
# ✅ Core libraries (pandas, numpy, matplotlib, seaborn)
# ✅ Financial libraries (yfinance, riskfolio, quantstats, pypfopt, ffn)
# Extensions to add: benzinga@1.5.0, bls@1.2.0, cftc@1.2.0, commodity@1.4.0, congress_gov@1.1.0, crypto@1.5.0, currency@1.5.0, derivatives@1.5.0, econdb@1.4.0, economy@1.5.0, equity@1.5.0, etf@1.5.0, federal_reserve@1.5.0, fixedincome@1.5.0, fmp@1.5.1, fred@1.5.0, imf@1.2.0, index@1.5.0, intrinio@1.5.0, news@1.5.0, oecd@1.5.0, polygon@1.5.0, regulators@1.5.0, sec@1.5.0, tiingo@1.5.0, tradingeconomics@1.5.0, us_eia@1.2.0, uscongress@1.1.0, yfinance@1.5.1
#
# Building...
# ✅ myPortfolioManagement package
#
# ================================================================================
# 🎉 SETUP COMPLETE - Ready to start!
# ================================================================================

# %% [markdown]
# ---
# ## <a id="section1"></a>📊 Section 1: Data Fetching (myData.py)
#
# Fetch historical price data for a diversified portfolio of ETFs.

# %%
from myPortfolioManagement.myData import (
    get_stock_prices,
    get_stock_info,
    get_option_exp_dates
)

# Define a diversified portfolio of ETFs
tickers = [
    'SPY',   # S&P 500
    'QQQ',   # Nasdaq 100
    'IWM',   # Russell 2000 (Small Cap)
    'EFA',   # International Developed
    'EEM',   # Emerging Markets
    'AGG',   # US Bonds
    'TIP',   # TIPS (Inflation Protected)
    'GLD',   # Gold
    'VNQ',   # Real Estate
    'DBC',   # Commodities
]

print("="*80)
print("SECTION 1: DATA FETCHING")
print("="*80)

print("\n1.1 📥 Fetching stock prices...")
print(f"Tickers: {', '.join(tickers)}")

# Fetch historical prices
prices = get_stock_prices(
    yahoo_tickers=tickers,
    start_date='2018-01-01',
    end_date='2024-12-01',
    freq='daily',
    wide_format=True
)

print(f"\n✅ Success!")
print(f"   Price data shape: {prices.shape}")
print(f"   Date range: {prices.index[0].strftime('%Y-%m-%d')} to {prices.index[-1].strftime('%Y-%m-%d')}")
print(f"   Trading days: {len(prices)}")
print("\n📋 First 5 rows:")
display(prices.head())
# Out:
# ================================================================================
# SECTION 1: DATA FETCHING
# ================================================================================
#
# 1.1 📥 Fetching stock prices...
# Tickers: SPY, QQQ, IWM, EFA, EEM, AGG, TIP, GLD, VNQ, DBC
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 21.75it/s][A
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  40%|████      | 4/10 [00:00<00:00,  8.71it/s]
#  60%|██████    | 6/10 [00:00<00:00,  6.24it/s]
#  80%|████████  | 8/10 [00:01<00:00,  5.45it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.59it/s]
# get_stock_prices took 3.341sec
#
# ✅ Success!
#    Price data shape: (1740, 10)
#    Date range: 2018-01-02 to 2024-11-29
#    Trading days: 1740
#
# 📋 First 5 rows:
# longname    Invesco DB Commodity Index Tracking Fund  Invesco QQQ Trust  SPDR Gold Shares  SPDR S&P 500 ETF  Vanguard Real Estate Index Fund ETF Shares  iShares Core U.S. Aggregate Bond ETF  \
# Date
# 2018-01-02                                   14.1104           150.4116          125.1500          237.2082                                     60.8142                               86.9814
# 2018-01-03                                   14.1949           151.8730          124.8200          238.7087                                     60.6377                               86.9894
# 2018-01-04                                   14.1780           152.1388          125.4600          239.7147                                     59.5931                               86.9336
# 2018-01-05                                   14.1273           153.6667          125.3300          241.3121                                     59.6225                               86.8778
# 2018-01-08                                   14.1188           154.2646          125.3100          241.7535                                     59.9315                               86.8539
#
# longname    iShares MSCI EAFE ETF  iShares MSCI Emerging Markets ETF  iShares Russell 2000 ETF  iShares TIPS Bond ETF
# Date
# 2018-01-02                55.6033                            39.9833                  139.1315                88.6666
# 2018-01-03                55.8702                            40.3664                  139.2761                88.7522
# 2018-01-04                56.4825                            40.5663                  139.6468                88.7756
# 2018-01-05                56.7966                            40.9160                  139.9361                88.7600
# 2018-01-08                56.7808                            40.9160                  140.1530                88.6666

# %%
print("1.2 ℹ️ Fetching stock information...")
stock_info = get_stock_info(tickers)
print("\n📋 Stock Information:")
display(stock_info[['yahooTicker', 'longName', 'type', 'currency', 'sector']])
# Out:
# 1.2 ℹ️ Fetching stock information...
#   0%|          | 0/10 [00:00<?, ?it/s]
#  40%|████      | 4/10 [00:00<00:00,  9.45it/s]
#  60%|██████    | 6/10 [00:00<00:00,  6.80it/s]
#  80%|████████  | 8/10 [00:01<00:00,  6.14it/s]
# 100%|██████████| 10/10 [00:01<00:00,  6.35it/s]
# 📋 Stock Information:
#   yahooTicker                                    longName type currency sector
# 0         SPY                            SPDR S&P 500 ETF  ETF      USD  Other
# 1         QQQ                           Invesco QQQ Trust  ETF      USD  Other
# 2         IWM                    iShares Russell 2000 ETF  ETF      USD  Other
# 3         EFA                       iShares MSCI EAFE ETF  ETF      USD  Other
# 4         EEM           iShares MSCI Emerging Markets ETF  ETF      USD  Other
# 5         AGG        iShares Core U.S. Aggregate Bond ETF  ETF      USD  Other
# 6         TIP                       iShares TIPS Bond ETF  ETF      USD  Other
# 7         GLD                            SPDR Gold Shares  ETF      USD  Other
# 8         VNQ  Vanguard Real Estate Index Fund ETF Shares  ETF      USD  Other
# 9         DBC    Invesco DB Commodity Index Tracking Fund  ETF      USD  Other

# %%
print("1.3 📈 Visualizing normalized prices...")

# Normalize prices to 100
normalized = prices / prices.iloc[0] * 100

fig, ax = plt.subplots(figsize=(14, 7))
normalized.plot(ax=ax, linewidth=2)
ax.set_title('Asset Performance (Normalized to 100)', fontsize=14, fontweight='bold')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Index Value', fontsize=12)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\n✅ Data fetching complete!")
# Out:
# 1.3 📈 Visualizing normalized prices...
# ✅ Data fetching complete!

# %% [markdown]
# ---
# ## <a id="section2"></a>📈 Section 2: Returns Calculation (myReturns.py)
#
# Calculate and analyze returns using different methods and frequencies.

# %%
from myPortfolioManagement.myReturns import (
    calculate_returns,
    average_returns,
    convert_returns_freq,
    calculate_portfolio_returns
)

print("="*80)
print("SECTION 2: RETURNS CALCULATION")
print("="*80)
# Out:
# ================================================================================
# SECTION 2: RETURNS CALCULATION
# ================================================================================

# %%
print("\n2.1 📊 Calculating daily returns...")
returns_daily = calculate_returns(prices, log_returns=False)
print(f"✅ Daily returns shape: {returns_daily.shape}")
print("\n📋 Daily returns (first 5 rows):")
display(returns_daily.head())
# Out:
# 2.1 📊 Calculating daily returns...
# ✅ Daily returns shape: (1739, 10)
#
# 📋 Daily returns (first 5 rows):
# longname    Invesco DB Commodity Index Tracking Fund  Invesco QQQ Trust  SPDR Gold Shares  SPDR S&P 500 ETF  Vanguard Real Estate Index Fund ETF Shares  iShares Core U.S. Aggregate Bond ETF  \
# Date
# 2018-01-03                                    0.0060             0.0097           -0.0026            0.0063                                     -0.0029                                0.0001
# 2018-01-04                                   -0.0012             0.0017            0.0051            0.0042                                     -0.0172                               -0.0006
# 2018-01-05                                   -0.0036             0.0100           -0.0010            0.0067                                      0.0005                               -0.0006
# 2018-01-08                                   -0.0006             0.0039           -0.0002            0.0018                                      0.0052                               -0.0003
# 2018-01-09                                    0.0066             0.0001           -0.0046            0.0023                                     -0.0129                               -0.0028
#
# longname    iShares MSCI EAFE ETF  iShares MSCI Emerging Markets ETF  iShares Russell 2000 ETF  iShares TIPS Bond ETF
# Date
# 2018-01-03                 0.0048                             0.0096                    0.0010                 0.0010
# 2018-01-04                 0.0110                             0.0050                    0.0027                 0.0003
# 2018-01-05                 0.0056                             0.0086                    0.0021                -0.0002
# 2018-01-08                -0.0003                             0.0000                    0.0016                -0.0011
# 2018-01-09                 0.0011                            -0.0016                   -0.0014                -0.0033

# %%
print("2.2 📊 Calculating log returns...")
returns_log = calculate_returns(prices, log_returns=True)
print("\n📋 Log returns statistics:")
display(returns_log.describe().T[['mean', 'std', 'min', 'max']])
# Out:
# 2.2 📊 Calculating log returns...
#
# 📋 Log returns statistics:
#                                              mean    std     min    max
# longname
# Invesco DB Commodity Index Tracking Fund   0.0002 0.0117 -0.0828 0.0469
# Invesco QQQ Trust                          0.0007 0.0153 -0.1276 0.0813
# SPDR Gold Shares                           0.0004 0.0090 -0.0552 0.0474
# SPDR S&P 500 ETF                           0.0005 0.0123 -0.1159 0.0867
# Vanguard Real Estate Index Fund ETF Shares 0.0002 0.0146 -0.1951 0.0861
# iShares Core U.S. Aggregate Bond ETF       0.0000 0.0038 -0.0408 0.0234
# iShares MSCI EAFE ETF                      0.0002 0.0116 -0.1164 0.0813
# iShares MSCI Emerging Markets ETF          0.0000 0.0136 -0.1333 0.0775
# iShares Russell 2000 ETF                   0.0003 0.0158 -0.1423 0.0875
# iShares TIPS Bond ETF                      0.0001 0.0040 -0.0291 0.0436

# %%
print("2.3 📅 Converting to monthly returns...")
returns_monthly = calculate_returns(prices, convert_to='monthly')
print(f"✅ Monthly returns shape: {returns_monthly.shape}")
print("\n📋 Monthly returns (last 12 months):")
display(returns_monthly.tail(12))
# Out:
# 2.3 📅 Converting to monthly returns...
# ✅ Monthly returns shape: (83, 10)
#
# 📋 Monthly returns (last 12 months):
# longname    Invesco DB Commodity Index Tracking Fund  Invesco QQQ Trust  SPDR Gold Shares  SPDR S&P 500 ETF  Vanguard Real Estate Index Fund ETF Shares  iShares Core U.S. Aggregate Bond ETF  \
# Date
# 2023-12-31                                   -0.0329             0.0559            0.0128            0.0457                                      0.0945                                0.0370
# 2024-01-31                                    0.0132             0.0182           -0.0142            0.0159                                     -0.0506                               -0.0015
# 2024-02-29                                   -0.0152             0.0528            0.0046            0.0522                                      0.0198                               -0.0147
# 2024-03-31                                    0.0446             0.0127            0.0867            0.0327                                      0.0195                                0.0090
# 2024-04-30                                    0.0161            -0.0437            0.0299           -0.0403                                     -0.0794                               -0.0248
# 2024-05-31                                   -0.0030             0.0615            0.0162            0.0506                                      0.0456                                0.0167
# 2024-06-30                                   -0.0017             0.0647           -0.0013            0.0353                                      0.0188                                0.0089
# 2024-07-31                                   -0.0280            -0.0168            0.0537            0.0121                                      0.0794                                0.0242
# 2024-08-31                                   -0.0208             0.0110            0.0209            0.0234                                      0.0522                                0.0146
# 2024-09-30                                    0.0072             0.0262            0.0509            0.0210                                      0.0327                                0.0133
# 2024-10-31                                    0.0144            -0.0086            0.0430           -0.0089                                     -0.0336                               -0.0252
# 2024-11-29                                   -0.0199             0.0535           -0.0312            0.0596                                      0.0426                                0.0111
#
# longname    iShares MSCI EAFE ETF  iShares MSCI Emerging Markets ETF  iShares Russell 2000 ETF  iShares TIPS Bond ETF
# Date
# 2023-12-31                 0.0535                             0.0357                    0.1213                 0.0244
# 2024-01-31                -0.0045                            -0.0453                   -0.0390                 0.0033
# 2024-02-29                 0.0299                             0.0417                    0.0563                -0.0105
# 2024-03-31                 0.0338                             0.0273                    0.0349                 0.0065
# 2024-04-30                -0.0324                            -0.0022                   -0.0685                -0.0169
# 2024-05-31                 0.0506                             0.0195                    0.0504                 0.0178
# 2024-06-30                -0.0183                             0.0262                   -0.0112                 0.0076
# 2024-07-31                 0.0259                             0.0085                    0.1034                 0.0173
# 2024-08-31                 0.0326                             0.0098                   -0.0169                 0.0080
# 2024-09-30                 0.0078                             0.0574                    0.0071                 0.0150
# 2024-10-31                -0.0527                            -0.0307                   -0.0142                -0.0185
# 2024-11-29                -0.0032                            -0.0268                    0.1107                 0.0050

# %%
print("2.4 💰 Calculating expected returns (different methods)...")

# Historical mean
mu_hist = average_returns(returns_daily, method='hist', periods=252)
print("\n📊 Expected Returns (Historical Mean):")
display(mu_hist.sort_values(ascending=False))

# Exponential Moving Average
mu_ema = average_returns(returns_daily, method='ema', span=500, periods=252)
print("\n📊 Expected Returns (EMA):")
display(mu_ema.sort_values(ascending=False))
# Out:
# 2.4 💰 Calculating expected returns (different methods)...
#
# 📊 Expected Returns (Historical Mean):
# longname
# Invesco QQQ Trust                            0.1923
# SPDR S&P 500 ETF                             0.1421
# SPDR Gold Shares                             0.1026
# iShares Russell 2000 ETF                     0.0812
# Vanguard Real Estate Index Fund ETF Shares   0.0644
# Invesco DB Commodity Index Tracking Fund     0.0544
# iShares MSCI EAFE ETF                        0.0448
# iShares TIPS Bond ETF                        0.0244
# iShares Core U.S. Aggregate Bond ETF         0.0125
# iShares MSCI Emerging Markets ETF            0.0055
# dtype: float64
# 📊 Expected Returns (EMA):
# longname
# Invesco QQQ Trust                            0.2855
# SPDR S&P 500 ETF                             0.2618
# iShares Russell 2000 ETF                     0.2541
# SPDR Gold Shares                             0.2285
# Vanguard Real Estate Index Fund ETF Shares   0.1798
# iShares MSCI EAFE ETF                        0.0833
# iShares MSCI Emerging Markets ETF            0.0685
# iShares Core U.S. Aggregate Bond ETF         0.0358
# iShares TIPS Bond ETF                        0.0303
# Invesco DB Commodity Index Tracking Fund     0.0026
# Name: 2024-11-29 00:00:00, dtype: float64

# %%
print("2.5 📊 Getting benchmark returns (S&P 500)...")

# Helper function to fix benchmark returns (handles quantstats compatibility)
def get_benchmark_returns_fixed(ticker='^GSPC', name='S&P500'):
    ret_data = qs.utils.download_returns(ticker)
    if isinstance(ret_data, pd.DataFrame):
        ret = ret_data.squeeze()
    else:
        ret = ret_data
    ret.name = name
    return pd.DataFrame(ret)

benchmark_sp500 = get_benchmark_returns_fixed('^GSPC', 'S&P500')
print(f"\n✅ S&P 500 benchmark shape: {benchmark_sp500.shape}")
display(benchmark_sp500.tail())

print("\n✅ Returns calculation complete!")
# Out:
# 2.5 📊 Getting benchmark returns (S&P 500)...
# [*********************100%***********************]  1 of 1 completed
# ✅ S&P 500 benchmark shape: (24612, 1)
#             S&P500
# Date
# 2025-12-17 -0.0116
# 2025-12-18  0.0079
# 2025-12-19  0.0088
# 2025-12-22  0.0064
# 2025-12-23  0.0046
# ✅ Returns calculation complete!

# %% [markdown]
# ---
# ## <a id="section3"></a>🔧 Section 3: Utility Functions (myUtils.py)
#
# Demonstrate utility functions for data manipulation and quality checks.

# %%
from myPortfolioManagement.myUtils import (
    data_overview,
    balance_dates,
    check_date_index,
    cap_outliersTS
)

print("="*80)
print("SECTION 3: UTILITY FUNCTIONS")
print("="*80)
# Out:
# ================================================================================
# SECTION 3: UTILITY FUNCTIONS
# ================================================================================

# %%
print("\n3.1 🔍 Data overview (checking data quality)...")
# Convert to long format for data_overview
prices_long = prices.reset_index().melt(
    id_vars='Date', 
    var_name='asset', 
    value_name='price'
)

overview = data_overview(
    prices_long,
    my_assets_col_name='asset',
    my_date_col_name='Date',
    price_col_name='price'
)
print("\n📋 Data Overview:")
display(overview)
# Out:
# 3.1 🔍 Data overview (checking data quality)...
#
# 📋 Data Overview:
#                                              Date_min   Date_max  trading_days  years_available  percentage_of_NAs
# asset
# Invesco DB Commodity Index Tracking Fund   2018-01-02 2024-11-29          2523           6.9123             0.0000
# Invesco QQQ Trust                          2018-01-02 2024-11-29          2523           6.9123             0.0000
# SPDR Gold Shares                           2018-01-02 2024-11-29          2523           6.9123             0.0000
# SPDR S&P 500 ETF                           2018-01-02 2024-11-29          2523           6.9123             0.0000
# Vanguard Real Estate Index Fund ETF Shares 2018-01-02 2024-11-29          2523           6.9123             0.0000
# iShares Core U.S. Aggregate Bond ETF       2018-01-02 2024-11-29          2523           6.9123             0.0000
# iShares MSCI EAFE ETF                      2018-01-02 2024-11-29          2523           6.9123             0.0000
# iShares MSCI Emerging Markets ETF          2018-01-02 2024-11-29          2523           6.9123             0.0000
# iShares Russell 2000 ETF                   2018-01-02 2024-11-29          2523           6.9123             0.0000
# iShares TIPS Bond ETF                      2018-01-02 2024-11-29          2523           6.9123             0.0000

# %%
print("3.2 ⚖️ Balancing dates between returns and benchmark...")
returns_balanced, benchmark_balanced = balance_dates(returns_daily, benchmark_sp500)
print(f"✅ Balanced returns shape: {returns_balanced.shape}")
print(f"✅ Balanced benchmark shape: {benchmark_balanced.shape}")
# Out:
# 3.2 ⚖️ Balancing dates between returns and benchmark...
# ✅ Balanced returns shape: (2005, 10)
# ✅ Balanced benchmark shape: (2005, 1)

# %%
print("3.3 ✂️ Capping outliers in time series...")
try:
    prices_capped = cap_outliersTS(
        returns_daily, 
        capping_method='iqr', 
        fold=3, 
        plot=False
    )
    print(f"✅ Capped prices shape: {prices_capped.shape}")
except Exception as e:
    print(f"⚠️ Outlier capping: {e}")

print("\n✅ Utility functions complete!")
# Out:
# 3.3 ✂️ Capping outliers in time series...
# ✅ Capped prices shape: (1677, 10)
#
# ✅ Utility functions complete!

# %% [markdown]
# ---
# ## <a id="section4"></a>🎯 Section 4: Portfolio Optimization (myPortfolioOptimisation.py)
#
# Generate optimal portfolio weights using various optimization methods.

# %%
from myPortfolioManagement.myPortfolioOptimisation import (
    HRP,
    equal_weight_portfolio,
    inverse_vol_portfolio,
    port_GMV,
    port_max_sharpe,
    port_target_return,
    port_target_volatility,
    port_CVAR,
    generate_rp_portfolios,
    risk_contributions
)

print("="*80)
print("SECTION 4: PORTFOLIO OPTIMIZATION")
print("="*80)

# Use returns for optimization (fill NaN with 0)
returns_opt = returns_daily.fillna(0)
# Out:
# ================================================================================
# SECTION 4: PORTFOLIO OPTIMIZATION
# ================================================================================

# %%
print("\n4.1 ⚖️ Equal Weight Portfolio...")
weights_equal = equal_weight_portfolio(returns_opt)
print("\n📊 Equal Weight Portfolio:")
display(weights_equal)
# Out:
# 4.1 ⚖️ Equal Weight Portfolio...
#
# 📊 Equal Weight Portfolio:
#                                             port_naive
# asset
# Invesco DB Commodity Index Tracking Fund        0.1000
# Invesco QQQ Trust                               0.1000
# SPDR Gold Shares                                0.1000
# SPDR S&P 500 ETF                                0.1000
# Vanguard Real Estate Index Fund ETF Shares      0.1000
# iShares Core U.S. Aggregate Bond ETF            0.1000
# iShares MSCI EAFE ETF                           0.1000
# iShares MSCI Emerging Markets ETF               0.1000
# iShares Russell 2000 ETF                        0.1000
# iShares TIPS Bond ETF                           0.1000

# %%
print("4.2 📉 Inverse Volatility Portfolio...")
weights_inv_vol = inverse_vol_portfolio(returns_opt, weight_max=0.25)
print("\n📊 Inverse Volatility Portfolio:")
display(weights_inv_vol.sort_values('port_inverse_vol', ascending=False))
# Out:
# 4.2 📉 Inverse Volatility Portfolio...
#
# 📊 Inverse Volatility Portfolio:
#                                             port_inverse_vol
# asset
# iShares Core U.S. Aggregate Bond ETF                  0.2299
# iShares TIPS Bond ETF                                 0.2165
# SPDR Gold Shares                                      0.0962
# iShares MSCI EAFE ETF                                 0.0756
# Invesco DB Commodity Index Tracking Fund              0.0743
# SPDR S&P 500 ETF                                      0.0706
# iShares MSCI Emerging Markets ETF                     0.0643
# Vanguard Real Estate Index Fund ETF Shares            0.0601
# Invesco QQQ Trust                                     0.0570
# iShares Russell 2000 ETF                              0.0554

# %%
print("4.3 🌳 Hierarchical Risk Parity (HRP)...")
weights_hrp = HRP(
    model='HRP',
    returns_training=returns_opt,
    codependence='pearson',
    covariance='ledoit',
    rm='MV',
    linkage='ward',
    weight_max=0.25,
    weight_min=0.02
)
print("\n📊 HRP Portfolio:")
display(weights_hrp.sort_values('port_weight', ascending=False))
# Out:
# 4.3 🌳 Hierarchical Risk Parity (HRP)...
#
# 📊 HRP Portfolio:
#                                             port_weight
# asset
# iShares TIPS Bond ETF                            0.2500
# iShares Core U.S. Aggregate Bond ETF             0.2500
# SPDR Gold Shares                                 0.1397
# SPDR S&P 500 ETF                                 0.1198
# Invesco DB Commodity Index Tracking Fund         0.0833
# iShares MSCI EAFE ETF                            0.0771
# Invesco QQQ Trust                                0.0200
# Vanguard Real Estate Index Fund ETF Shares       0.0200
# iShares MSCI Emerging Markets ETF                0.0200
# iShares Russell 2000 ETF                         0.0200

# %%
print("4.4 🌲 HERC (Hierarchical Equal Risk Contribution)...")
weights_herc = HRP(
    model='HERC',
    returns_training=returns_opt,
    codependence='pearson',
    rm='CVaR',
    weight_max=0.30,
    weight_min=0.02
)
print("\n📊 HERC Portfolio:")
display(weights_herc.sort_values('port_weight', ascending=False))
# Out:
# 4.4 🌲 HERC (Hierarchical Equal Risk Contribution)...
#
# 📊 HERC Portfolio:
#                                             port_weight
# asset
# iShares TIPS Bond ETF                            0.3000
# iShares Core U.S. Aggregate Bond ETF             0.3000
# SPDR Gold Shares                                 0.1938
# Invesco DB Commodity Index Tracking Fund         0.0862
# Invesco QQQ Trust                                0.0200
# SPDR S&P 500 ETF                                 0.0200
# Vanguard Real Estate Index Fund ETF Shares       0.0200
# iShares MSCI EAFE ETF                            0.0200
# iShares MSCI Emerging Markets ETF                0.0200
# iShares Russell 2000 ETF                         0.0200

# %%
print("4.5 📉 Global Minimum Variance Portfolio...")
weights_gmv = port_GMV(
    returns_training=returns_opt,
    weight_min=0.02,
    weight_max=0.30
)
print("\n📊 Global Minimum Variance Portfolio:")
display(weights_gmv.sort_values('port_min_vol', ascending=False))
# Out:
# 4.5 📉 Global Minimum Variance Portfolio...
#
# 📊 Global Minimum Variance Portfolio:
#                                             port_min_vol
# asset
# iShares TIPS Bond ETF                             0.3000
# iShares Core U.S. Aggregate Bond ETF              0.3000
# SPDR Gold Shares                                  0.1770
# Invesco DB Commodity Index Tracking Fund          0.0994
# SPDR S&P 500 ETF                                  0.0236
# Invesco QQQ Trust                                 0.0200
# Vanguard Real Estate Index Fund ETF Shares        0.0200
# iShares MSCI EAFE ETF                             0.0200
# iShares MSCI Emerging Markets ETF                 0.0200
# iShares Russell 2000 ETF                          0.0200

# %%
print("4.6 📈 Maximum Sharpe Ratio Portfolio...")
weights_max_sharpe = port_max_sharpe(
    returns_training=returns_opt,
    rf=0.04,
    weight_min=0.02,
    weight_max=0.30
)
print("\n📊 Max Sharpe Portfolio:")
display(weights_max_sharpe.sort_values('port_max_Sharpe', ascending=False))
# Out:
# 4.6 📈 Maximum Sharpe Ratio Portfolio...
#
# 📊 Max Sharpe Portfolio:
#                                             port_max_Sharpe
# asset
# SPDR Gold Shares                                     0.3000
# Invesco QQQ Trust                                    0.2944
# iShares TIPS Bond ETF                                0.2656
# Invesco DB Commodity Index Tracking Fund             0.0200
# Vanguard Real Estate Index Fund ETF Shares           0.0200
# SPDR S&P 500 ETF                                     0.0200
# iShares Core U.S. Aggregate Bond ETF                 0.0200
# iShares MSCI EAFE ETF                                0.0200
# iShares MSCI Emerging Markets ETF                    0.0200
# iShares Russell 2000 ETF                             0.0200

# %%
print("4.7 🛡️ Minimum CVaR Portfolio...")
weights_cvar = port_CVAR(
    returns_training=returns_opt,
    confidence_interval=0.95,
    rf=0.04,
    weight_min=0.02,
    weight_max=0.30
)
print("\n📊 Minimum CVaR Portfolio:")
display(weights_cvar.sort_values('port_target_CVAR', ascending=False))
# Out:
# 4.7 🛡️ Minimum CVaR Portfolio...
#
# 📊 Minimum CVaR Portfolio:
#                                             port_target_CVAR
# asset
# iShares TIPS Bond ETF                                 0.3000
# iShares Core U.S. Aggregate Bond ETF                  0.3000
# SPDR Gold Shares                                      0.1811
# Invesco DB Commodity Index Tracking Fund              0.0893
# SPDR S&P 500 ETF                                      0.0296
# Invesco QQQ Trust                                     0.0200
# Vanguard Real Estate Index Fund ETF Shares            0.0200
# iShares MSCI EAFE ETF                                 0.0200
# iShares MSCI Emerging Markets ETF                     0.0200
# iShares Russell 2000 ETF                              0.0200

# %%
# Compare all portfolios
# First, let's inspect the structure of each weights dataframe
print("Inspecting weight dataframes...")
print("\nweights_equal columns:", weights_equal.columns.tolist())
print("weights_inv_vol columns:", weights_inv_vol.columns.tolist())
print("weights_hrp columns:", weights_hrp.columns.tolist())
print("weights_herc columns:", weights_herc.columns.tolist())
print("weights_gmv columns:", weights_gmv.columns.tolist())
print("weights_max_sharpe columns:", weights_max_sharpe.columns.tolist())
print("weights_cvar columns:", weights_cvar.columns.tolist())

# Now build the comparison dataframe more robustly
all_weights = pd.DataFrame(index=weights_hrp.index)

# Extract weights, handling different column names
all_weights['Equal'] = weights_equal['port_naive'].values if 'port_naive' in weights_equal.columns else weights_equal.iloc[:, -1].values
all_weights['Inv_Vol'] = weights_inv_vol['port_inverse_vol'].values if 'port_inverse_vol' in weights_inv_vol.columns else weights_inv_vol.iloc[:, -1].values
all_weights['HRP'] = weights_hrp['port_weight'].values if 'port_weight' in weights_hrp.columns else weights_hrp.iloc[:, -1].values
all_weights['HERC'] = weights_herc['port_weight'].values if 'port_weight' in weights_herc.columns else weights_herc.iloc[:, -1].values

# For GMV, Max_Sharpe, and CVaR - handle cases where 'asset' might be index or column
if 'asset' in weights_gmv.columns:
    all_weights['GMV'] = weights_gmv.set_index('asset')['port_min_vol']
else:
    all_weights['GMV'] = weights_gmv['port_min_vol'].values if 'port_min_vol' in weights_gmv.columns else weights_gmv.iloc[:, -1].values

if 'asset' in weights_max_sharpe.columns:
    all_weights['Max_Sharpe'] = weights_max_sharpe.set_index('asset')['port_max_Sharpe']
else:
    all_weights['Max_Sharpe'] = weights_max_sharpe['port_max_Sharpe'].values if 'port_max_Sharpe' in weights_max_sharpe.columns else weights_max_sharpe.iloc[:, -1].values

if 'asset' in weights_cvar.columns:
    all_weights['Min_CVaR'] = weights_cvar.set_index('asset')['port_target_CVAR']
else:
    all_weights['Min_CVaR'] = weights_cvar['port_target_CVAR'].values if 'port_target_CVAR' in weights_cvar.columns else weights_cvar.iloc[:, -1].values

print("\nAll Portfolio Weights Comparison:")
all_weights.round(3)
# Out:
# Inspecting weight dataframes...
#
# weights_equal columns: ['port_naive']
# weights_inv_vol columns: ['port_inverse_vol']
# weights_hrp columns: ['port_weight']
# weights_herc columns: ['port_weight']
# weights_gmv columns: ['port_min_vol']
# weights_max_sharpe columns: ['port_max_Sharpe']
# weights_cvar columns: ['port_target_CVAR']
#
# All Portfolio Weights Comparison:
#                                             Equal  Inv_Vol    HRP   HERC    GMV  Max_Sharpe  Min_CVaR
# asset
# Invesco DB Commodity Index Tracking Fund   0.1000   0.0740 0.0830 0.0860 0.0990      0.0200    0.0890
# Invesco QQQ Trust                          0.1000   0.0570 0.0200 0.0200 0.0200      0.2940    0.0200
# SPDR Gold Shares                           0.1000   0.0960 0.1400 0.1940 0.1770      0.3000    0.1810
# SPDR S&P 500 ETF                           0.1000   0.0710 0.1200 0.0200 0.0240      0.0200    0.0300
# Vanguard Real Estate Index Fund ETF Shares 0.1000   0.0600 0.0200 0.0200 0.0200      0.0200    0.0200
# iShares Core U.S. Aggregate Bond ETF       0.1000   0.2300 0.2500 0.3000 0.3000      0.0200    0.3000
# iShares MSCI EAFE ETF                      0.1000   0.0760 0.0770 0.0200 0.0200      0.0200    0.0200
# iShares MSCI Emerging Markets ETF          0.1000   0.0640 0.0200 0.0200 0.0200      0.0200    0.0200
# iShares Russell 2000 ETF                   0.1000   0.0550 0.0200 0.0200 0.0200      0.0200    0.0200
# iShares TIPS Bond ETF                      0.1000   0.2160 0.2500 0.3000 0.3000      0.2660    0.3000

# %%
# Visualize
fig, ax = plt.subplots(figsize=(14, 6))
all_weights.plot(kind='bar', ax=ax, width=0.8)
ax.set_title('Portfolio Weights Comparison', fontsize=14, fontweight='bold')
ax.set_xlabel('Asset', fontsize=12)
ax.set_ylabel('Weight', fontsize=12)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\n✅ Portfolio optimization complete!")
# Out:
# ✅ Portfolio optimization complete!

# %% [markdown]
# ---
# ## <a id="section5"></a>📊 Section 5: Performance Metrics (myPerformanceMetrics.py)
#
# Calculate comprehensive risk and return metrics.

# %%
from myPortfolioManagement.myPerformanceMetrics import (
    get_main_stats,
    alpha_beta_table,
    alpha_beta_bull,
    alpha_beta_bear,
    information_ratio,
    drawdown_details,
    assets_drawdown_details,
    performance_overview,
    cagr,
    beta_Co_Moments_table
)

print("="*80)
print("SECTION 5: PERFORMANCE METRICS")
print("="*80)
# Out:
# ================================================================================
# SECTION 5: PERFORMANCE METRICS
# ================================================================================

# %%
print("\n5.1 📊 Main Performance Statistics...")
main_stats = get_main_stats(returns_daily, rf=0.04, smart=True)
print("\n📋 Main Performance Stats:")
display(main_stats.round(4))
# Out:
# 5.1 📊 Main Performance Statistics...
# get_main_stats took 254.83ms
#
# 📋 Main Performance Stats:
#                                             total_ret   cagr  adjusted_sortino  sharpe  calmar  max_drawdown
# Invesco DB Commodity Index Tracking Fund       0.4410 0.0543            0.2544  0.2689  0.1303       -0.4171
# Invesco QQQ Trust                              2.3664 0.1922            0.8453  0.8517  0.5473       -0.3512
# SPDR Gold Shares                               0.9624 0.1026            0.6540  0.6525  0.4661       -0.2200
# SPDR S&P 500 ETF                               1.5023 0.1421            0.7253  0.7400  0.4213       -0.3372
# Vanguard Real Estate Index Fund ETF Shares     0.5381 0.0643            0.3003  0.3121  0.1518       -0.4240
# iShares Core U.S. Aggregate Bond ETF           0.0897 0.0125           -0.2351 -0.2472  0.0679       -0.1843
# iShares MSCI EAFE ETF                          0.3528 0.0447            0.2036  0.2119  0.1308       -0.3419
# iShares MSCI Emerging Markets ETF              0.0389 0.0055            0.0080  0.0083  0.0139       -0.3982
# iShares Russell 2000 ETF                       0.7140 0.0812            0.3746  0.3815  0.1973       -0.4113
# iShares TIPS Bond ETF                          0.1813 0.0244           -0.0167 -0.0165  0.1683       -0.1451

# %%
print("5.2 📈 CAGR Calculation...")
cagr_values = cagr(prices)
print("\n📋 Compound Annual Growth Rate:")
display(cagr_values.sort_values(ascending=False).round(4))
# Out:
# 5.2 📈 CAGR Calculation...
#
# 📋 Compound Annual Growth Rate:
# Invesco QQQ Trust                            0.1921
# SPDR S&P 500 ETF                             0.1420
# SPDR Gold Shares                             0.1025
# iShares Russell 2000 ETF                     0.0811
# Vanguard Real Estate Index Fund ETF Shares   0.0643
# Invesco DB Commodity Index Tracking Fund     0.0543
# iShares MSCI EAFE ETF                        0.0447
# iShares TIPS Bond ETF                        0.0244
# iShares Core U.S. Aggregate Bond ETF         0.0125
# iShares MSCI Emerging Markets ETF            0.0055
# dtype: float64

# %%
print("5.3 🎯 Alpha-Beta Analysis (Full Market)...")
ab_table = alpha_beta_table(
    returns=returns_daily,
    returns_benchmark=benchmark_sp500,
    rf=0.04
)
print("\n📋 Alpha-Beta Table:")
display(ab_table)
# Out:
# 5.3 🎯 Alpha-Beta Analysis (Full Market)...
#
# 📋 Alpha-Beta Table:
#                                              alpha  alpha_bull  alpha_bear   beta  beta_bull  beta_bear
# asset
# Invesco DB Commodity Index Tracking Fund   -1.0000     -0.9800     -0.9300 0.2900     0.1900     0.4100
# Invesco QQQ Trust                           0.0800     -0.0100     -0.3200 1.0000     0.9400     0.9600
# SPDR Gold Shares                           -1.0000     -0.9900     -0.9900 0.0700     0.0700     0.0600
# SPDR S&P 500 ETF                           -0.7300     -0.5100     -0.4200 0.8700     0.8400     0.8900
# Vanguard Real Estate Index Fund ETF Shares -0.9000     -0.7300     -0.1600 0.7800     0.7700     0.8900
# iShares Core U.S. Aggregate Bond ETF       -1.0000     -0.9900     -0.9900 0.0400     0.0400     0.0300
# iShares MSCI EAFE ETF                      -0.9500     -0.8100     -0.7200 0.7000     0.6700     0.7400
# iShares MSCI Emerging Markets ETF          -0.9400     -0.8000     -0.7300 0.7300     0.6600     0.7600
# iShares Russell 2000 ETF                   -0.3500     -0.3500     -0.1500 0.9600     0.8800     0.9800
# iShares TIPS Bond ETF                      -1.0000     -0.9900     -0.9900 0.0200     0.0000     0.0100

# %%
print("5.4 📉 Drawdown Details (for SPY)...")
spy_prices = prices.iloc[:, 0]
dd_details = drawdown_details(spy_prices, top_drawdowns=5)
print(f"\n📋 Top 5 Drawdowns for {prices.columns[0]}:")
display(dd_details)

print("\n✅ Performance metrics complete!")
# Out:
# 5.4 📉 Drawdown Details (for SPY)...
#
# 📋 Top 5 Drawdowns for Invesco DB Commodity Index Tracking Fund:
#          start      valley         end  days  Years  max drawdown  Peak Price  Bottom Price
# 11  2018-10-04  2020-04-27  2021-04-28   938      3      -42.0000     16.0000        9.0000
# 34  2022-06-10  2023-05-31  2024-11-29   904      2      -27.0000     26.0000       19.0000
# 29  2022-03-09  2022-03-16  2022-04-13    36      0      -13.0000     22.0000       21.0000
# 23  2021-10-21  2021-12-01  2022-01-14    86      0      -12.0000     19.0000       17.0000
# 10  2018-05-24  2018-08-15  2018-10-02   132      0      -10.0000     15.0000       14.0000
# ✅ Performance metrics complete!

# %% [markdown]
# ---
# ## <a id="section6"></a>🔬 Section 6: Low-Level Risk Metrics (metrics.py)
#
# Calculate individual risk metrics using low-level functions.

# %%
from myPortfolioManagement.metrics import (
    vol, beta, var, cvar, lpm, hpm,
    max_dd, dd, sharpe_ratio, sortino_ratio,
    treynor_ratio, calmar_ratio, omega_ratio,
    gain_loss_ratio, upside_potential_ratio
)

print("="*80)
print("SECTION 6: LOW-LEVEL RISK METRICS")
print("="*80)

# Use SPY returns for demonstration
spy_returns = returns_daily.iloc[:, 0].dropna().values
market_returns = benchmark_sp500.squeeze().dropna().values

# Align lengths
min_len = min(len(spy_returns), len(market_returns))
spy_returns = spy_returns[:min_len]
market_returns = market_returns[:min_len]
# Out:
# ================================================================================
# SECTION 6: LOW-LEVEL RISK METRICS
# ================================================================================

# %%
print("\n6.1 📊 Basic Risk Metrics...")
print(f"Volatility (annualized): {vol(spy_returns) * np.sqrt(252):.4f}")
print(f"Beta to market: {beta(spy_returns, market_returns):.4f}")
# Out:
# 6.1 📊 Basic Risk Metrics...
# Volatility (annualized): 0.1854
# Beta to market: -0.0001

# %%
print("6.2 💰 Value at Risk...")
print(f"VaR (5%): {var(spy_returns, 0.05):.4f}")
print(f"CVaR (5%): {cvar(spy_returns, 0.05):.4f}")
# Out:
# 6.2 💰 Value at Risk...
# VaR (5%): 0.0186
# CVaR (5%): 0.0286

# %%
print("6.3 📉 Drawdown Metrics...")
print(f"Maximum Drawdown: {max_dd(spy_returns):.4f}")
print(f"Drawdown (30 days): {dd(spy_returns, 30):.4f}")
# Out:
# 6.3 📉 Drawdown Metrics...
# Maximum Drawdown: 0.1185
# Drawdown (30 days): 0.0878

# %%
print("6.4 📈 Risk-Adjusted Return Ratios...")
er = np.mean(spy_returns) * 252  # Annualized expected return
rf = 0.04  # Risk-free rate

print(f"Sharpe Ratio: {sharpe_ratio(er, spy_returns, rf/252):.4f}")
print(f"Sortino Ratio: {sortino_ratio(er, spy_returns, rf/252):.4f}")
print(f"Treynor Ratio: {treynor_ratio(er, spy_returns, market_returns, rf/252):.4f}")
print(f"Calmar Ratio: {calmar_ratio(er, spy_returns, rf/252):.4f}")
print(f"Omega Ratio: {omega_ratio(er, spy_returns, rf/252):.4f}")

print("\n✅ Risk metrics complete!")
# Out:
# 6.4 📈 Risk-Adjusted Return Ratios...
# Sharpe Ratio: 6.0006
# Sortino Ratio: 8.0739
# Treynor Ratio: -921.4742
# Calmar Ratio: 0.5914
# Omega Ratio: 16.8960
#
# ✅ Risk metrics complete!

# %% [markdown]
# ---
# ## <a id="section7"></a>🔄 Section 7: Backtesting & Simulation (myBacktesting.py)
#
# Test portfolio strategies using Monte Carlo and bootstrap methods.

# %%
from myPortfolioManagement.myBacktesting import (
    bootstrap_stats,
    bootstrap_portfolio_performance,
    sim_series,
    beating_probability,
    performance
)

print("="*80)
print("SECTION 7: BACKTESTING & SIMULATION")
print("="*80)

# Create a simple portfolio return series for backtesting
portfolio_returns = returns_daily.mean(axis=1)  # Equal weighted proxy
portfolio_returns.name = 'Portfolio'
# Out:
# ✓ GPU acceleration available via CuPy
# ================================================================================
# SECTION 7: BACKTESTING & SIMULATION
# ================================================================================

# %%
print("\n7.1 🎲 Bootstrap Statistics (500 simulations)...")
print("This may take 30-60 seconds...")

bootstrap_results = bootstrap_stats(
    returns=portfolio_returns,
    returns_benchmark=benchmark_sp500.squeeze(),
    rf=0.04,
    periods=252,
    n_sim=500
)
print("\n📊 Bootstrap Statistics Distribution:")
display(bootstrap_results.describe().round(4))
# Out:
# 7.1 🎲 Bootstrap Statistics (500 simulations)...
# This may take 30-60 seconds...
#   Generating 500 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 14.975sec
# bootstrap_stats took 14.976sec
#
# 📊 Bootstrap Statistics Distribution:
#         cagr  volatility   sharpe  sortino    alpha     beta
# count 0.0000    400.0000 400.0000 400.0000 400.0000 400.0000
# mean     NaN      0.1314   0.3519   0.3427  -0.9793   0.6179
# std      NaN      0.0042   0.2565   0.2538   0.0017   0.0080
# min      NaN      0.1237  -0.1502  -0.1399  -0.9822   0.6031
# 25%      NaN      0.1276   0.1484   0.1405  -0.9806   0.6119
# 50%      NaN      0.1314   0.3626   0.3437  -0.9794   0.6180
# 75%      NaN      0.1347   0.5615   0.5476  -0.9779   0.6245
# max      NaN      0.1398   0.8416   0.8345  -0.9759   0.6331

# %%
print("7.2 📊 Bootstrap Portfolio Performance (In-Sample vs Out-of-Sample)...")
print("This may take 1-2 minutes...")

try:
    means, distributions, dist_stats = bootstrap_portfolio_performance(
        returns=portfolio_returns,
        returns_benchmark=benchmark_sp500.squeeze(),
        periods=252,
        rf=0.04,
        out_of_sample_date='2023-01-01',
        n_sim=500
    )
    print("\n📋 Mean Performance Metrics:")
    display(means.round(4))
except Exception as e:
    print(f"⚠️ Bootstrap performance analysis: {e}")
# Out:
# 7.2 📊 Bootstrap Portfolio Performance (In-Sample vs Out-of-Sample)...
# This may take 1-2 minutes...
# Computing in-sample bootstrap...
#   Generating 500 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 7.838sec
# Computing out-of-sample bootstrap...
#   Generating 500 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 7.911sec
# Computing full sample bootstrap...
#   Generating 500 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 7.919sec
# bootstrap_portfolio_performance took 23.703sec
#
# 📋 Mean Performance Metrics:
#             in_sample  out_of_sample  all_sample
# cagr              NaN            NaN         NaN
# volatility     0.1426         0.0956      0.1312
# sharpe         0.1719         1.1363      0.3809
# sortino        0.1698         1.2067      0.3728
# alpha         -0.9794        -0.9757     -0.9792
# beta           0.6169         0.6338      0.6182

# %%
print("7.3 🎯 Probability of Beating Benchmark...")
print("Running Monte Carlo simulation...")

try:
    beat_prob = beating_probability(
        returns=pd.DataFrame(portfolio_returns),
        returns_benchmark=benchmark_sp500,
        n_sample=500
    )
    prob_value = beat_prob.values[0][0]
    print(f"\n✅ Probability of beating S&P 500: {prob_value:.1%}")
except Exception as e:
    print(f"⚠️ Beating probability calculation: {e}")

print("\n✅ Backtesting complete!")
# Out:
# 7.3 🎯 Probability of Beating Benchmark...
# Running Monte Carlo simulation...
# ⚠️ Beating probability calculation: name 'balance_dates' is not defined
#
# ✅ Backtesting complete!

# %% [markdown]
# ---
# ## <a id="section8"></a>🔁 Section 8: Bootstrapping (myBootstrapping.py)
#
# Resample data using various bootstrap methods.

# %%
from myPortfolioManagement.myBootstrapping import (
    BootstrapIDD,
    BootstrapStationary,
    BootstrapCircular,
    BootstrapMovingBlock,
    bootstrappingTS
)

print("="*80)
print("SECTION 8: BOOTSTRAPPING")
print("="*80)

# Use single asset returns for bootstrapping
single_returns = returns_daily.iloc[:, 0].dropna()
# Out:
# ✓ GPU acceleration available via CuPy
# ================================================================================
# SECTION 8: BOOTSTRAPPING
# ================================================================================

# %%
print("\n8.1 🎲 IID Bootstrap...")
bs_iid = BootstrapIDD(series=single_returns, n_samples=100, seed=42)
print(f"✅ IID Bootstrap shape: {bs_iid.shape}")
print(f"Original std: {single_returns.std():.6f}")
print(f"Bootstrap mean std: {bs_iid.std().mean():.6f}")
# Out:
# 8.1 🎲 IID Bootstrap...
# bootstrap_iid_gpu took 128.99ms
# ✅ IID Bootstrap shape: (1739, 100)
# Original std: 0.011684
# Bootstrap mean std: 0.011702

# %%
print("8.2 📊 Stationary Bootstrap...")
bs_stationary = BootstrapStationary(
    series=single_returns,
    block_size=20,
    n_samples=100,
    seed=42
)
print(f"✅ Stationary Bootstrap shape: {bs_stationary.shape}")

print("\n✅ Bootstrapping complete!")
# Out:
# 8.2 📊 Stationary Bootstrap...
# ✅ Stationary Bootstrap shape: (1739, 100)
#
# ✅ Bootstrapping complete!

# %% [markdown]
# ## GPU Enabled Boostrapping

# %%
# First, check the CUDA version on Kaggle
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Tue Dec 23 23:20:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0             26W /   70W |     123MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install --upgrade joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)

# %%
# Install CuPy for CUDA 12.x
# !pip install cupy-cuda12x

# Verify installation
# !python -c "import cupy as cp; print(f'CuPy Version: {cp.__version__}'); print(f'CUDA Version: {cp.cuda.runtime.runtimeGetVersion()}')"
# Out:
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (13.3.0)
# Requirement already satisfied: numpy<2.3,>=1.22 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x) (2.0.2)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x) (0.8.3)
# CuPy Version: 13.3.0
# CUDA Version: 12060

# %%
print("=" * 70)
print("CUDA 12.5 SETUP FOR KAGGLE")
print("=" * 70)

# Step 1: Uninstall old versions
print("\n1️⃣ Removing old CuPy installations...")
# !pip uninstall cupy cupy-cuda11x cupy-cuda12x -y -q

# Step 2: Install correct version
print("\n2️⃣ Installing CuPy for CUDA 12.x...")
# !pip install cupy-cuda12x -q

print("\n3️⃣ Verifying installation...")

# Test import
try:
    import cupy as cp
    print(f"✓ CuPy version: {cp.__version__}")
    print(f"✓ CUDA Runtime version: {cp.cuda.runtime.runtimeGetVersion()}")
    
    # Test GPU access
    device_count = cp.cuda.runtime.getDeviceCount()
    print(f"✓ GPU devices found: {device_count}")
    
    for i in range(device_count):
        props = cp.cuda.runtime.getDeviceProperties(i)
        print(f"  GPU {i}: {props['name'].decode()}")
        print(f"    Compute Capability: {props['major']}.{props['minor']}")
        print(f"    Total Memory: {props['totalGlobalMem'] / 1024**3:.2f} GB")
    
    # Test basic operation
    test_array = cp.array([1, 2, 3, 4, 5])
    result = cp.sum(test_array)
    print(f"\n✓ Basic GPU operation successful: sum([1,2,3,4,5]) = {result}")
    
    # Test memory management
    mempool = cp.get_default_memory_pool()
    print(f"✓ Memory pool accessible")
    cp.get_default_memory_pool().free_all_blocks()
    print(f"✓ Memory management working")
    
    print("\n✅ CUDA 12.x setup complete! GPU acceleration ready.")
    GPU_AVAILABLE = True
    
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()
    GPU_AVAILABLE = False

print("=" * 70)
# Out:
# ======================================================================
# CUDA 12.5 SETUP FOR KAGGLE
# ======================================================================
#
# 1️⃣ Removing old CuPy installations...
# WARNING: Skipping cupy as it is not installed.
# WARNING: Skipping cupy-cuda11x as it is not installed.
#
# 2️⃣ Installing CuPy for CUDA 12.x...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
#
# 3️⃣ Verifying installation...
# ✓ CuPy version: 13.3.0
# ✓ CUDA Runtime version: 12060
# ✓ GPU devices found: 2
#   GPU 0: Tesla T4
#     Compute Capability: 7.5
#     Total Memory: 14.74 GB
#   GPU 1: Tesla T4
#     Compute Capability: 7.5
#     Total Memory: 14.74 GB
#
# ✓ Basic GPU operation successful: sum([1,2,3,4,5]) = 15
# ✓ Memory pool accessible
# ✓ Memory management working
#
# ✅ CUDA 12.x setup complete! GPU acceleration ready.
# ======================================================================

# %%
print("=" * 70)
print("COMPLETE CUPY CLEANUP AND REINSTALL")
print("=" * 70)

# 1. Uninstall ALL CuPy versions
print("\n1️⃣ Removing all CuPy installations...")
# !pip uninstall cupy cupy-cuda11x cupy-cuda12x cupy-cuda118 cupy-cuda120 -y

# 2. Clear pip cache
print("\n2️⃣ Clearing pip cache...")
# !pip cache purge

# 3. Install correct version for CUDA 12.5
print("\n3️⃣ Installing cupy-cuda12x for CUDA 12.5...")
# !pip install cupy-cuda12x

print("\n4️⃣ Verifying installation...")
import importlib
import sys

# Force reload of cupy if it was already imported
if 'cupy' in sys.modules:
    del sys.modules['cupy']
    print("   Cleared cached cupy module")

try:
    import cupy as cp
    print(f"✓ CuPy version: {cp.__version__}")
    print(f"✓ CUDA Runtime: {cp.cuda.runtime.runtimeGetVersion()}")
    
    # Check what CUDA version CuPy is compiled for
    # CUDA 12.5 = 12005
    cuda_version = cp.cuda.runtime.runtimeGetVersion()
    cuda_major = cuda_version // 1000
    cuda_minor = (cuda_version % 1000) // 10
    print(f"✓ CUDA version detected: {cuda_major}.{cuda_minor}")
    
    if cuda_major == 12:
        print("✅ Correct CuPy version installed for CUDA 12.x!")
    else:
        print(f"⚠️ Warning: CuPy expecting CUDA {cuda_major}.x but system has CUDA 12.5")
        
except Exception as e:
    print(f"❌ Error: {e}")

print("\n" + "=" * 70)
print("⚠️ IMPORTANT: After running this cell, select:")
print("   Kernel → Restart Kernel")
print("   Then re-run your notebook from the beginning")
print("=" * 70)
# Out:
# ======================================================================
# COMPLETE CUPY CLEANUP AND REINSTALL
# ======================================================================
#
# 1️⃣ Removing all CuPy installations...
# WARNING: Skipping cupy as it is not installed.
# WARNING: Skipping cupy-cuda11x as it is not installed.
# Found existing installation: cupy-cuda12x 13.6.0
# Uninstalling cupy-cuda12x-13.6.0:
#   Successfully uninstalled cupy-cuda12x-13.6.0
# WARNING: Skipping cupy-cuda118 as it is not installed.
# WARNING: Skipping cupy-cuda120 as it is not installed.
#
# 2️⃣ Clearing pip cache...
# Files removed: 555 (277.7 MB)
#
# 3️⃣ Installing cupy-cuda12x for CUDA 12.5...
# Collecting cupy-cuda12x
#   Downloading cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy<2.6,>=1.22 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x) (2.0.2)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x) (0.8.3)
# Downloading cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl (112.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 MB 73.8 MB/s  0:00:01m0:00:0100:01
# Installing collected packages: cupy-cuda12x
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# Successfully installed cupy-cuda12x-13.6.0
#
# 4️⃣ Verifying installation...
#    Cleared cached cupy module
# ✓ CuPy version: 13.3.0
# ✓ CUDA Runtime: 12060
# ✓ CUDA version detected: 12.6
# ✅ Correct CuPy version installed for CUDA 12.x!
#
# ======================================================================
# ⚠️ IMPORTANT: After running this cell, select:
#    Kernel → Restart Kernel
#    Then re-run your notebook from the beginning
# ======================================================================

# %%
# GPU Setup for Kaggle CUDA 12.5
print("🚀 Initializing GPU acceleration...")

try:
    import cupy as cp
    
    # Verify CUDA is accessible
    device_count = cp.cuda.runtime.getDeviceCount()
    
    if device_count > 0:
        props = cp.cuda.runtime.getDeviceProperties(0)
        print(f"✓ GPU Available: {device_count} device(s)")
        print(f"  GPU: {props['name'].decode()}")
        print(f"  CUDA Version: {cp.cuda.runtime.runtimeGetVersion()}")
        print(f"  Memory: {props['totalGlobalMem'] / 1024**3:.1f} GB")
        
        # Clear GPU memory
        cp.get_default_memory_pool().free_all_blocks()
        cp.get_default_pinned_memory_pool().free_all_blocks()
        
        GPU_AVAILABLE = True
        print("  Status: Ready ✅\n")
    else:
        print("⚠️ No GPU devices found")
        GPU_AVAILABLE = False
        
except Exception as e:
    print(f"⚠️ GPU initialization failed: {e}")
    print("  Falling back to CPU mode\n")
    GPU_AVAILABLE = False
    cp = None
# Out:
# 🚀 Initializing GPU acceleration...
# ✓ GPU Available: 2 device(s)
#   GPU: Tesla T4
#   CUDA Version: 12060
#   Memory: 14.7 GB
#   Status: Ready ✅

# %%
print("=" * 70)
print("7.2 📊 Bootstrap Portfolio Performance")
print("=" * 70)

# ============================================
# STEP 1: Data Validation and Cleaning
# ============================================
print("\n🔍 Validating input data...")

# Clean portfolio returns
portfolio_returns_clean = portfolio_returns.copy()
if isinstance(portfolio_returns_clean, pd.DataFrame):
    portfolio_returns_clean = portfolio_returns_clean.squeeze()

# Clean benchmark
benchmark_clean = benchmark_sp500.squeeze().copy()

# Remove NaN values
portfolio_returns_clean = portfolio_returns_clean.dropna()
benchmark_clean = benchmark_clean.dropna()

print(f"   Portfolio: {len(portfolio_returns_clean)} observations")
print(f"   Date range: {portfolio_returns_clean.index[0]} to {portfolio_returns_clean.index[-1]}")
print(f"   Benchmark: {len(benchmark_clean)} observations")
print(f"   Date range: {benchmark_clean.index[0]} to {benchmark_clean.index[-1]}")

# Align dates - find common date range
common_start = max(portfolio_returns_clean.index[0], benchmark_clean.index[0])
common_end = min(portfolio_returns_clean.index[-1], benchmark_clean.index[-1])

portfolio_returns_clean = portfolio_returns_clean[
    (portfolio_returns_clean.index >= common_start) & 
    (portfolio_returns_clean.index <= common_end)
]
benchmark_clean = benchmark_clean[
    (benchmark_clean.index >= common_start) & 
    (benchmark_clean.index <= common_end)
]

print(f"\n   Aligned range: {common_start} to {common_end}")
print(f"   Portfolio: {len(portfolio_returns_clean)} observations")
print(f"   Benchmark: {len(benchmark_clean)} observations")

# Verify out-of-sample date is valid
out_of_sample_date = '2023-01-01'
oos_date = pd.to_datetime(out_of_sample_date)

if oos_date < common_start or oos_date > common_end:
    print(f"\n⚠️ Warning: Out-of-sample date {out_of_sample_date} is outside data range")
    print(f"   Adjusting to midpoint of available data...")
    # Use midpoint
    midpoint_idx = len(portfolio_returns_clean) // 2
    out_of_sample_date = portfolio_returns_clean.index[midpoint_idx].strftime('%Y-%m-%d')
    print(f"   New out-of-sample date: {out_of_sample_date}")

# Check for remaining NaNs
if portfolio_returns_clean.isna().any():
    print(f"⚠️ Removing {portfolio_returns_clean.isna().sum()} NaN values from portfolio")
    portfolio_returns_clean = portfolio_returns_clean.dropna()

if benchmark_clean.isna().any():
    print(f"⚠️ Removing {benchmark_clean.isna().sum()} NaN values from benchmark")
    benchmark_clean = benchmark_clean.dropna()

# Final alignment using merge
print("\n   Final alignment using inner join...")
df_aligned = pd.DataFrame({
    'portfolio': portfolio_returns_clean,
    'benchmark': benchmark_clean
}).dropna()

portfolio_returns_final = df_aligned['portfolio']
benchmark_final = df_aligned['benchmark']

print(f"   Final aligned data: {len(portfolio_returns_final)} observations")
print(f"   Date range: {portfolio_returns_final.index[0]} to {portfolio_returns_final.index[-1]}")

# Verify data quality
print(f"\n✓ Portfolio stats: mean={portfolio_returns_final.mean():.6f}, std={portfolio_returns_final.std():.6f}")
print(f"✓ Benchmark stats: mean={benchmark_final.mean():.6f}, std={benchmark_final.std():.6f}")
print(f"✓ No NaN values: Portfolio={not portfolio_returns_final.isna().any()}, Benchmark={not benchmark_final.isna().any()}")
# Out:
# ======================================================================
# 7.2 📊 Bootstrap Portfolio Performance
# ======================================================================
#
# 🔍 Validating input data...
#    Portfolio: 1739 observations
#    Date range: 2018-01-03 00:00:00 to 2024-11-29 00:00:00
#    Benchmark: 24611 observations
#    Date range: 1928-01-03 00:00:00 to 2025-12-23 00:00:00
#
#    Aligned range: 2018-01-03 00:00:00 to 2024-11-29 00:00:00
#    Portfolio: 1739 observations
#    Benchmark: 1739 observations
#
#    Final alignment using inner join...
#    Final aligned data: 1739 observations
#    Date range: 2018-01-03 00:00:00 to 2024-11-29 00:00:00
#
# ✓ Portfolio stats: mean=0.000343, std=0.008305
# ✓ Benchmark stats: mean=0.000541, std=0.012460
# ✓ No NaN values: Portfolio=True, Benchmark=True

# %%
# ============================================
# STEP 2: Run Bootstrap
# ============================================
# Import unified function with automatic GPU detection
from myPortfolioManagement.myBacktesting import bootstrap_portfolio_performance

if GPU_AVAILABLE:
    print("\n🚀 Using GPU-accelerated version")
    n_sim = 5000
else:
    print("\n💻 Using CPU-optimized version")
    n_sim = 2000

print(f"📊 Running {n_sim:,} simulations...\n")

try:
    import time
    start_time = time.time()

    # The function now auto-detects GPU availability
    means, distributions, dist_stats = bootstrap_portfolio_performance(
        returns=portfolio_returns_final,
        returns_benchmark=benchmark_final,
        periods=252,
        rf=0.04,
        out_of_sample_date=out_of_sample_date,
        n_sim=n_sim,
        use_gpu=None  # Auto-detect (or True to force GPU, False to force CPU)
    )

    elapsed = time.time() - start_time

    print(f"\n✅ Completed in {elapsed:.1f} seconds")
    print(f"   Throughput: {n_sim/elapsed:.0f} simulations/second")
    print(f"   Per simulation: {elapsed/n_sim*1000:.2f} ms")

    # Check for NaN in results
    if means.isna().any().any():
        print("\n⚠️ WARNING: NaN values detected in results!")
        print("\nNaN counts by metric:")
        print(means.isna().sum())
    else:
        print("\n📋 Mean Performance Metrics:")
        display(means.round(4))

        print("\n📊 Distribution Statistics:")
        display(dist_stats[['mean', 'std', '25%', '50%', '75%']].round(4))

except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()

print("\n" + "=" * 70)
# Out:
# 🚀 Using GPU-accelerated version
# 📊 Running 5,000 simulations...
#
# Computing in-sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 79.745sec
# Computing out-of-sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 77.702sec
# Computing full sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 68.013sec
# bootstrap_portfolio_performance took 225.495sec
#
# ✅ Completed in 225.5 seconds
#    Throughput: 22 simulations/second
#    Per simulation: 45.10 ms
#
# ⚠️ WARNING: NaN values detected in results!
#
# NaN counts by metric:
# in_sample        1
# out_of_sample    1
# all_sample       1
# dtype: int64
#
# ======================================================================

# %%
# Check GPU availability
print("🚀 Checking GPU availability...")
try:
    import cupy as cp
    print(f"✓ GPU Available: {cp.cuda.runtime.getDeviceCount()} device(s)")
    print(f"  GPU: {cp.cuda.runtime.getDeviceProperties(0)['name'].decode()}")
    GPU_AVAILABLE = True
except:
    print("⚠️ GPU not available, using CPU")
    GPU_AVAILABLE = False

# Import unified function with automatic GPU detection
from myPortfolioManagement.myBacktesting import bootstrap_portfolio_performance

print("\n7.2 📊 Bootstrap Portfolio Performance (Auto GPU Detection)...")
print(f"Running {500 if not GPU_AVAILABLE else 5000} simulations...")

try:
    # The function now auto-detects GPU availability
    means, distributions, dist_stats = bootstrap_portfolio_performance(
        returns=portfolio_returns,
        returns_benchmark=benchmark_sp500.squeeze(),
        periods=252,
        rf=0.04,
        out_of_sample_date='2023-01-01',
        n_sim=5000 if GPU_AVAILABLE else 500,  # 10x more sims with GPU!
        use_gpu=None  # Auto-detect (or True to force GPU, False to force CPU)
    )

    print("\n📋 Mean Performance Metrics:")
    display(means.round(4))

    print("\n📊 Distribution Statistics:")
    display(dist_stats.round(4))

except Exception as e:
    print(f"⚠️ Bootstrap performance analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🚀 Checking GPU availability...
# ✓ GPU Available: 2 device(s)
#   GPU: Tesla T4
#
# 7.2 📊 Bootstrap Portfolio Performance (Auto GPU Detection)...
# Running 5000 simulations...
# Computing in-sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 76.967sec
# Computing out-of-sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 78.217sec
# Computing full sample bootstrap...
#   Generating 5000 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 68.480sec
# bootstrap_portfolio_performance took 223.699sec
#
# 📋 Mean Performance Metrics:
#             in_sample  out_of_sample  all_sample
# cagr              NaN            NaN         NaN
# volatility     0.1428         0.0954      0.1314
# sharpe         0.1852         1.1344      0.3625
# sortino        0.1831         1.2047      0.3536
# alpha         -0.9795        -0.9756     -0.9791
# beta           0.6166         0.6342      0.6187
# 📊 Distribution Statistics:
#                           count    mean    std     min     25%     50%     75%     max
# cagr_in_sample           0.0000     NaN    NaN     NaN     NaN     NaN     NaN     NaN
# volatility_in_sample  4000.0000  0.1428 0.0054  0.1327  0.1385  0.1427  0.1469  0.1536
# sharpe_in_sample      4000.0000  0.1852 0.3025 -0.4041 -0.0584  0.1919  0.4212  0.7712
# sortino_in_sample     4000.0000  0.1831 0.2923 -0.3688 -0.0540  0.1826  0.4092  0.7678
# alpha_in_sample       4000.0000 -0.9795 0.0017 -0.9827 -0.9809 -0.9795 -0.9781 -0.9759
# beta_in_sample        4000.0000  0.6166 0.0085  0.5998  0.6098  0.6168  0.6235  0.6328
# cagr_out_sample          0.0000     NaN    NaN     NaN     NaN     NaN     NaN     NaN
# volatility_out_sample 4000.0000  0.0954 0.0022  0.0911  0.0938  0.0954  0.0972  0.0997
# sharpe_out_sample     4000.0000  1.1344 0.4866  0.1833  0.7537  1.1337  1.5138  2.0801
# sortino_out_sample    4000.0000  1.2047 0.5426  0.1843  0.7753  1.1901  1.6276  2.2985
# alpha_out_sample      4000.0000 -0.9756 0.0037 -0.9820 -0.9785 -0.9758 -0.9728 -0.9677
# beta_out_sample       4000.0000  0.6342 0.0144  0.6059  0.6229  0.6344  0.6457  0.6616
# cagr                     0.0000     NaN    NaN     NaN     NaN     NaN     NaN     NaN
# volatility            4000.0000  0.1314 0.0042  0.1237  0.1281  0.1314  0.1347  0.1399
# sharpe                4000.0000  0.3625 0.2517 -0.1158  0.1621  0.3597  0.5683  0.8524
# sortino               4000.0000  0.3536 0.2496 -0.1068  0.1521  0.3456  0.5537  0.8560
# alpha                 4000.0000 -0.9791 0.0016 -0.9821 -0.9804 -0.9792 -0.9779 -0.9759
# beta                  4000.0000  0.6187 0.0076  0.6038  0.6126  0.6188  0.6248  0.6331

# %%
# Test performance improvement
import time

print("=" * 60)
print("PERFORMANCE COMPARISON: CPU vs GPU Bootstrap")
print("=" * 60)

test_returns = portfolio_returns.squeeze()
test_benchmark = benchmark_sp500.squeeze()

# Test configurations
test_configs = [
    (100, "Quick test"),
    (500, "Standard"),
    (2000, "Heavy")
]

for n_sim, desc in test_configs:
    print(f"\n{desc}: {n_sim} simulations")
    print("-" * 40)
    
    # CPU version
    print("CPU (original):", end=" ")
    start = time.time()
    try:
        from myPortfolioManagement.myBacktesting import bootstrap_portfolio_performance
        _, _, _ = bootstrap_portfolio_performance(
            returns=test_returns,
            returns_benchmark=test_benchmark,
            n_sim=n_sim,
            out_of_sample_date='2023-01-01',
            use_gpu=False
        )
        cpu_time = time.time() - start
        print(f"{cpu_time:.2f}s")
    except Exception as e:
        print(f"Error - {e}")
        cpu_time = None
    
    # GPU version
    if GPU_AVAILABLE:
        print("GPU (optimized):", end=" ")
        start = time.time()
        try:
            _, _, _ = bootstrap_portfolio_performance(
                returns=test_returns,
                returns_benchmark=test_benchmark,
                n_sim=n_sim,
                out_of_sample_date='2023-01-01',
                use_gpu=True
            )
            gpu_time = time.time() - start
            print(f"{gpu_time:.2f}s")
            
            if cpu_time:
                speedup = cpu_time / gpu_time
                print(f"  → Speedup: {speedup:.1f}x faster!")
        except Exception as e:
            print(f"Error - {e}")
# Out:
# ============================================================
# PERFORMANCE COMPARISON: CPU vs GPU Bootstrap
# ============================================================
#
# Quick test: 100 simulations
# ----------------------------------------
# CPU (original): bootstrap_stats took 10.595sec
# bootstrap_stats took 10.519sec
# bootstrap_stats took 10.621sec
# bootstrap_portfolio_performance took 31.763sec
# 31.76s
# GPU (optimized): Computing in-sample bootstrap...
#   Generating 100 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 6.653sec
# Computing out-of-sample bootstrap...
#   Generating 100 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 1.705sec
# Computing full sample bootstrap...
#   Generating 100 random samples...
#   Computing metrics in parallel...
# bootstrap_stats_vectorized took 1.828sec
# bootstrap_portfolio_performance took 10.214sec
# 10.21s
#   → Speedup: 3.1x faster!
#
# Standard: 500 simulations
# ----------------------------------------
# CPU (original): bootstrap_stats took 52.898sec
# bootstrap_stats took 52.895sec

# %% [markdown]
# ---
# ## <a id="section9"></a>🔍 Section 9: Clustering & Analysis (myClustering.py)
#
# Group similar assets and detect market regimes.

# %%
from myPortfolioManagement.myClustering import (
    ts_clustering,
    cluster_ftca,
    detect_regimes
)

print("="*80)
print("SECTION 9: CLUSTERING & ANALYSIS")
print("="*80)
# Out:
# ================================================================================
# SECTION 9: CLUSTERING & ANALYSIS
# ================================================================================

# %%
print("\n9.1 🔗 Time Series Clustering (DTW)...")

try:
    clusters, cluster_centers = ts_clustering(
        df=prices,
        number_of_clusters=3,
        algo='dtw',
        plot_bar_center=False
    )
    print("\n📊 Asset Clusters:")
    display(clusters)
    print(f"\n✅ Cluster Centers shape: {cluster_centers.shape}")
except Exception as e:
    print(f"⚠️ Time series clustering: {e}")
# Out:
# 9.1 🔗 Time Series Clustering (DTW)...
#
# 📊 Asset Clusters:
#                                            Cluster
# asset
# iShares Core U.S. Aggregate Bond ETF             1
# iShares TIPS Bond ETF                            1
# iShares MSCI Emerging Markets ETF                2
# Invesco DB Commodity Index Tracking Fund         3
# Invesco QQQ Trust                                3
# SPDR Gold Shares                                 3
# SPDR S&P 500 ETF                                 3
# Vanguard Real Estate Index Fund ETF Shares       3
# iShares MSCI EAFE ETF                            3
# iShares Russell 2000 ETF                         3
# ✅ Cluster Centers shape: (1740, 3)

# %%
print("9.2 ⚡ Fast Threshold Clustering Algorithm (FTCA)...")

try:
    ftca_clusters = cluster_ftca(
        returns=returns_daily,
        threshold=0.50,
        col_name='asset'
    )
    print("\n📊 FTCA Clusters:")
    display(ftca_clusters)
except Exception as e:
    print(f"⚠️ FTCA clustering: {e}")

print("\n✅ Clustering complete!")
# Out:
# 9.2 ⚡ Fast Threshold Clustering Algorithm (FTCA)...
#
# 📊 FTCA Clusters:
#    cluster                                       asset
# 0        1                       iShares MSCI EAFE ETF
# 1        1                           Invesco QQQ Trust
# 2        1                            SPDR S&P 500 ETF
# 3        1  Vanguard Real Estate Index Fund ETF Shares
# 4        1           iShares MSCI Emerging Markets ETF
# 5        1                    iShares Russell 2000 ETF
# 6        2                       iShares TIPS Bond ETF
# 7        2        iShares Core U.S. Aggregate Bond ETF
# 8        3                            SPDR Gold Shares
# 9        4    Invesco DB Commodity Index Tracking Fund
# ✅ Clustering complete!

# %% [markdown]
# ---
# ## <a id="section10"></a>📊 Section 10: Visualization (myPlots.py)
#
# Create comprehensive charts and plots.

# %%
from myPortfolioManagement.myPlots import (
    correlation_matrix,
    monthly_heatmap,
    scatter_plot_simple
)

print("="*80)
print("SECTION 10: VISUALIZATION")
print("="*80)
# Out:
# ================================================================================
# SECTION 10: VISUALIZATION
# ================================================================================

# %%
print("\n10.1 🔗 Correlation Matrix...")
correlation_matrix(
    returns_daily,
    corr_limit=None,
    figsize=(12, 8),
    diagonal=True
)
plt.show()
# Out:
# 10.1 🔗 Correlation Matrix...

# %%
print("10.2 📅 Monthly Returns Heatmap...")
try:
    fig = monthly_heatmap(
        returns=portfolio_returns,
        annot_size=8,
        figsize=(12, 8),
        cbar=True,
        eoy=True,
        show=True
    )
except Exception as e:
    print(f"⚠️ Monthly heatmap: {e}")
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# 10.2 📅 Monthly Returns Heatmap...
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
# Risk-Return Scatter Plot
risk_return = pd.DataFrame({
    'Return': returns_daily.mean() * 252,
    'Volatility': returns_daily.std() * np.sqrt(252)
})

scatter_plot_simple(risk_return, x='Volatility', y='Return')
plt.title('Risk-Return Profile')
plt.show()

# %%
print("10.3 📈 Portfolio Cumulative Returns Comparison...")

# Calculate returns for different strategies
portfolio_comparison = pd.DataFrame({
    'Equal_Weight': (returns_daily * pd.Series(weights_equal['port_naive'].to_dict())).sum(axis=1),
    'HRP': (returns_daily * pd.Series(weights_hrp['port_weight'].to_dict())).sum(axis=1),
    'Max_Sharpe': (returns_daily * pd.Series(weights_max_sharpe['port_max_Sharpe'].to_dict())).sum(axis=1),  # Fixed: removed .set_index('asset')
    'SPY_Benchmark': returns_daily.iloc[:, 0]
})

# Cumulative returns
cum_returns = (1 + portfolio_comparison).cumprod()

fig, ax = plt.subplots(figsize=(14, 7))
cum_returns.plot(ax=ax, linewidth=2)
ax.set_title('Cumulative Returns: Portfolio Strategies Comparison', fontsize=14, fontweight='bold')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Growth of $1', fontsize=12)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\n📋 Final Values (Growth of $1):")
display(cum_returns.iloc[-1].round(4))
print("\n✅ Visualization complete!")
# Out:
# 10.3 📈 Portfolio Cumulative Returns Comparison...
# 📋 Final Values (Growth of $1):
# Equal_Weight    1.7082
# HRP             1.5068
# Max_Sharpe      2.0520
# SPY_Benchmark   1.4410
# Name: 2024-11-29 00:00:00, dtype: float64
# ✅ Visualization complete!

# %% [markdown]
# ---
# ## <a id="section11"></a>🎲 Section 11: Portfolio Selection (myPortfolioSelection.py)
#
# Generate all possible portfolio combinations.

# %%
from myPortfolioManagement.myPortfolioSelection import (
    possible_combinations,
    all_combinations_inner_loop
)

print("="*80)
print("SECTION 11: PORTFOLIO SELECTION")
print("="*80)
# Out:
# ================================================================================
# SECTION 11: PORTFOLIO SELECTION
# ================================================================================

# %%
print("\n11.1 🎲 Generating all possible portfolio combinations...")
assets = ['SPY', 'QQQ', 'IWM', 'AGG', 'GLD']

# All combinations of 2-4 assets
combinations = possible_combinations(
    assets_to_consider=assets,
    min_assets=2,
    max_assets=4
)
print(f"\n✅ Number of possible portfolios (2-4 assets): {len(combinations)}")
print("\nFirst 10 combinations:")
for i, combo in enumerate(combinations[:10]):
    print(f"  {i+1}. {combo}")
# Out:
# 11.1 🎲 Generating all possible portfolio combinations...
# possible_combinations took 0.018ms
#
# ✅ Number of possible portfolios (2-4 assets): 25
#
# First 10 combinations:
#   1. ['SPY', 'QQQ']
#   2. ['SPY', 'IWM']
#   3. ['SPY', 'AGG']
#   4. ['SPY', 'GLD']
#   5. ['QQQ', 'IWM']
#   6. ['QQQ', 'AGG']
#   7. ['QQQ', 'GLD']
#   8. ['IWM', 'AGG']
#   9. ['IWM', 'GLD']
#   10. ['AGG', 'GLD']

# %%
print("11.2 🎯 Combinations with must-have assets...")
combinations_must_have = possible_combinations(
    assets_to_consider=assets,
    min_assets=3,
    max_assets=4,
    must_have=['SPY', 'AGG']  # Must include these
)
print(f"\n✅ Portfolios that must include SPY and AGG: {len(combinations_must_have)}")
for combo in combinations_must_have:
    print(f"  {combo}")

print("\n✅ Portfolio selection complete!")
# Out:
# 11.2 🎯 Combinations with must-have assets...
# possible_combinations took 0.021ms
#
# ✅ Portfolios that must include SPY and AGG: 6
#   ['SPY', 'QQQ', 'AGG']
#   ['SPY', 'IWM', 'AGG']
#   ['SPY', 'AGG', 'GLD']
#   ['SPY', 'QQQ', 'IWM', 'AGG']
#   ['SPY', 'QQQ', 'AGG', 'GLD']
#   ['SPY', 'IWM', 'AGG', 'GLD']
#
# ✅ Portfolio selection complete!

# %% [markdown]
# ---
# ## <a id="section12"></a>🎯 Section 12: Complete Workflow - End to End Example
#
# This section demonstrates a complete portfolio management workflow:
# 1. Fetch data
# 2. Calculate returns
# 3. Optimize portfolio
# 4. Backtest strategy
# 5. Analyze performance

# %%
print("="*80)
print("SECTION 12: COMPLETE WORKFLOW - END TO END EXAMPLE")
print("="*80)

# Step 1: Data already fetched above
print("\n✅ Step 1: Using previously fetched data...")
print(f"  Assets: {list(prices.columns)}")
print(f"  Period: {prices.index[0].strftime('%Y-%m-%d')} to {prices.index[-1].strftime('%Y-%m-%d')}")
# Out:
# ================================================================================
# SECTION 12: COMPLETE WORKFLOW - END TO END EXAMPLE
# ================================================================================
#
# ✅ Step 1: Using previously fetched data...
#   Assets: ['Invesco DB Commodity Index Tracking Fund', 'Invesco QQQ Trust', 'SPDR Gold Shares', 'SPDR S&P 500 ETF', 'Vanguard Real Estate Index Fund ETF Shares', 'iShares Core U.S. Aggregate Bond ETF', 'iShares MSCI EAFE ETF', 'iShares MSCI Emerging Markets ETF', 'iShares Russell 2000 ETF', 'iShares TIPS Bond ETF']
#   Period: 2018-01-02 to 2024-11-29

# %%
# Step 2: Split into training and testing
split_date = '2023-01-01'
returns_train = returns_daily[returns_daily.index < split_date]
returns_test = returns_daily[returns_daily.index >= split_date]
print(f"\n✅ Step 2: Train/Test Split at {split_date}")
print(f"  Training: {len(returns_train)} days")
print(f"  Testing: {len(returns_test)} days")
# Out:
# ✅ Step 2: Train/Test Split at 2023-01-01
#   Training: 1258 days
#   Testing: 481 days

# %%
# Step 3: Optimize portfolios on training data
print("\n✅ Step 3: Optimizing portfolios on training data...")
weights_hrp_train = HRP(
    model='HRP',
    returns_training=returns_train.fillna(0),
    weight_max=0.25,
    weight_min=0.02
)
print("  HRP weights optimized")

weights_equal_train = equal_weight_portfolio(returns_train)
print("  Equal weight portfolio created")
# Out:
# ✅ Step 3: Optimizing portfolios on training data...
#   HRP weights optimized
#   Equal weight portfolio created

# %%
# Step 4: Calculate out-of-sample returns
print("\n✅ Step 4: Calculating out-of-sample returns...")

# HRP portfolio returns
hrp_weights_dict = weights_hrp_train['port_weight'].to_dict()
portfolio_hrp_test = (returns_test * pd.Series(hrp_weights_dict)).sum(axis=1)
portfolio_hrp_test.name = 'HRP'

# Equal weight returns
equal_weights_dict = weights_equal_train['port_naive'].to_dict()
portfolio_equal_test = (returns_test * pd.Series(equal_weights_dict)).sum(axis=1)
portfolio_equal_test.name = 'Equal_Weight'

# Combine for comparison
portfolio_comparison = pd.DataFrame({
    'HRP': portfolio_hrp_test,
    'Equal_Weight': portfolio_equal_test,
    'SPY_Benchmark': returns_test.iloc[:, 0]  # SPY as benchmark
})
# Out:
# ✅ Step 4: Calculating out-of-sample returns...

# %%
# Step 5: Performance analysis
print("\n✅ Step 5: Out-of-Sample Performance Analysis...")
test_stats = get_main_stats(portfolio_comparison, rf=0.04)
print("\n📋 Out-of-Sample Performance Metrics:")
display(test_stats.round(4))

# Cumulative returns
cum_returns = (1 + portfolio_comparison).cumprod()
print("\n📋 Cumulative Returns (End of Period):")
display(cum_returns.iloc[-1].round(4))
# Out:
# ✅ Step 5: Out-of-Sample Performance Analysis...
# get_main_stats took 114.17ms
#
# 📋 Out-of-Sample Performance Metrics:
#                total_ret    cagr  adjusted_sortino  sharpe  calmar  max_drawdown
# HRP               0.2352  0.1172            1.5565  1.4692  1.9355       -0.0606
# Equal_Weight      0.3126  0.1534            1.5725  1.4899  1.8440       -0.0832
# SPY_Benchmark    -0.0577 -0.0307           -0.3564 -0.3700 -0.2221       -0.1382
# 📋 Cumulative Returns (End of Period):
# HRP             1.2352
# Equal_Weight    1.3126
# SPY_Benchmark   0.9423
# Name: 2024-11-29 00:00:00, dtype: float64

# %% [markdown]
# ---
# ## 📊 Final Summary
#
# Comprehensive analysis summary and key findings.

# %%
print("\n" + "="*80)
print("SUMMARY & KEY FINDINGS")
print("="*80)

print(f"""
🎉 Portfolio Management Analysis Complete!

📊 DATA ANALYZED:
- Assets: {len(tickers)} ETFs across multiple asset classes
- Period: {prices.index[0].strftime('%Y-%m-%d')} to {prices.index[-1].strftime('%Y-%m-%d')}
- Trading Days: {len(prices)}

🎯 OPTIMIZATION STRATEGIES TESTED:
- Equal Weight (Naive 1/N)
- Inverse Volatility
- Hierarchical Risk Parity (HRP)
- Hierarchical Equal Risk Contribution (HERC)
- Global Minimum Variance (GMV)
- Maximum Sharpe Ratio
- Minimum CVaR

📈 BEST PERFORMING ASSET:
- Ticker: {cagr_values.idxmax()}
- CAGR: {cagr_values.max():.2%}

📉 WORST PERFORMING ASSET:
- Ticker: {cagr_values.idxmin()}
- CAGR: {cagr_values.min():.2%}

💡 NEXT STEPS:
1. Review portfolio weights and adjust constraints
2. Run more extensive backtests with different parameters
3. Implement rebalancing strategy
4. Add transaction costs and slippage
5. Consider regime-based allocation

✅ All sections completed successfully!
""")

print("="*80)
print("END OF TUTORIAL")
print("="*80)
# Out:
# ================================================================================
# SUMMARY & KEY FINDINGS
# ================================================================================
#
# 🎉 Portfolio Management Analysis Complete!
#
# 📊 DATA ANALYZED:
# - Assets: 10 ETFs across multiple asset classes
# - Period: 2018-01-02 to 2024-11-29
# - Trading Days: 1740
#
# 🎯 OPTIMIZATION STRATEGIES TESTED:
# - Equal Weight (Naive 1/N)
# - Inverse Volatility
# - Hierarchical Risk Parity (HRP)
# - Hierarchical Equal Risk Contribution (HERC)
# - Global Minimum Variance (GMV)
# - Maximum Sharpe Ratio
# - Minimum CVaR
#
# 📈 BEST PERFORMING ASSET:
# - Ticker: Invesco QQQ Trust
# - CAGR: 19.21%
#
# 📉 WORST PERFORMING ASSET:
# - Ticker: iShares MSCI Emerging Markets ETF
# - CAGR: 0.55%
#
# 💡 NEXT STEPS:
# 1. Review portfolio weights and adjust constraints
# 2. Run more extensive backtests with different parameters
# 3. Implement rebalancing strategy
# 4. Add transaction costs and slippage
# 5. Consider regime-based allocation
#
# ✅ All sections completed successfully!
#
# ================================================================================
# END OF TUTORIAL
# ================================================================================

# %% [markdown]
# ---
# ## 📚 Additional Resources
#
# **Documentation:**
# - [GitHub Repository](https://github.com/ferhat00/QuantitativePortfolioManagement)
# - [Riskfolio-Lib Docs](https://riskfolio-lib.readthedocs.io/)
# - [PyPortfolioOpt Docs](https://pyportfolioopt.readthedocs.io/)
#
# **Further Reading:**
# - Hierarchical Risk Parity (López de Prado, 2016)
# - Modern Portfolio Theory (Markowitz, 1952)
# - Risk-based and Factor Investing (Ang, 2014)
#
# **Key Concepts Demonstrated:**
# 1. ✅ Data fetching and preprocessing
# 2. ✅ Returns calculation (simple, log, different frequencies)
# 3. ✅ Portfolio optimization (7+ methods)
# 4. ✅ Performance metrics and risk analysis
# 5. ✅ Backtesting and Monte Carlo simulation
# 6. ✅ Asset clustering and regime detection
# 7. ✅ Comprehensive visualization
# 8. ✅ Complete end-to-end workflow
#
# ---
# *Created with ❤️ for quantitative portfolio management*
#
# *Compatible with Kaggle and Google Colab*
