# %%
import warnings
warnings.filterwarnings('ignore')

# for interactive 
#from itables import init_notebook_mode
#init_notebook_mode(all_interactive = True)
#import itables.options as opt
#opt.maxBytes = 2**20
#opt.maxColumns= 0

import pyfolio as pf
import yfinance as yf

# %%
# pip show numpy
# !pip install pandas==1.3.5

# %%
# %cd /Users/safishajjouz/GitHub/QuantitativePortfolioManagement
# Out:
# /Users/safishajjouz/GitHub/QuantitativePortfolioManagement

# %%
from myPortfolioManagement.myData import * 
from myPortfolioManagement.myPortfolioOptimisation import *
from myPortfolioManagement.myReturns import *
from myPortfolioManagement.myPerformanceAnalytics import *
from myPortfolioManagement.myBacktesting import *

# %% [markdown]
# ### Portfolio Tickers and Candidate Portfolios
#
# - Global Equities
# - Absolute Return
# - Commodities
# - Precious Metals and Gold
# - Bonds
# - Direct Property
# - 60/40 Portfolio
# - UK Credit
# - Cash

# %%
df_prices = load_fidelity_prices()

# %%
drop_funds = ['HgCapital Trust Ord', 
              'L&G Cash Trust I Acc',
              'Vanguard UK Infl-Lnkd Gilt Idx £ Inc', 
              'WisdomTree Physical Precious Metals ETC GBP', 
              'M&G Emerging Markets Bond GBP I Inc', 
              'Royal London Sterl Extra Yld Bd A',
              'Royal London Sustainable Div C Acc', 
              'Vanguard Glb Bd Idx £ H Dist',
              'VT Argonaut Absolute Return R GBP Acc',
              'Invesco EQQQ NASDAQ-100 ETF GBP',
               'Allianz Strategic Bond C Inc',
              #  'SLI UK Real Estate Platform 1 Inc', 
              # 'Vanguard UK Infl-Lnkd Gilt Idx £ Inc',
              #'Invesco EQQQ NASDAQ-100 ETF GBP'] 
               'HarbourVest Global Priv Equity Ord']
              #'Scottish Mortgage Ord']
              # 'Vanguard UK Infl-Lnkd Gilt Idx £ Inc', 
              # 'Vanguard Glb Bd Idx £ H Dist',
              # 'M&G Emerging Markets Bond GBP I Inc'
df_prices = df_prices[-df_prices['fund'].isin(drop_funds)]

# %%
df_plot = df_prices.pivot_table(index='Date', 
                                columns='fund', 
                                values='price')

# %%
ret = calculate_returns(df_plot)
performance_overview(ret)
# Out:
#                                               start        end   rf  \
# BlackRock Ntrl Resources Gr & Inc D Acc  2011-05-07 2022-02-25  0.0
# SLI UK Real Estt Accumulation Fdr P1Inc  2016-03-19 2022-02-25  0.0
# Scottish Mortgage Ord                    2000-01-02 2022-02-25  0.0
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc 2009-06-24 2022-02-25  0.0
# WisdomTree Physical Gold GBP             2007-10-30 2022-02-25  0.0
# iShares $ TIPS ETF USD Acc GBP           2006-12-13 2022-02-25  0.0
#
#                                          total_return      cagr max_drawdown  \
# BlackRock Ntrl Resources Gr & Inc D Acc       0.66368  0.048232    -0.429337
# SLI UK Real Estt Accumulation Fdr P1Inc       -0.0444 -0.007619    -0.166824
# Scottish Mortgage Ord                        9.400208  0.111521    -0.636268
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc       4.0815  0.136858    -0.255935
# WisdomTree Physical Gold GBP                 2.505749   0.09152    -0.420556
# iShares $ TIPS ETF USD Acc GBP               1.734074  0.068394    -0.177685
#
#                                             calmar       mtd three_month  \
# BlackRock Ntrl Resources Gr & Inc D Acc   0.112341  0.037017     0.10252
# SLI UK Real Estt Accumulation Fdr P1Inc  -0.045669 -0.001672    0.025542
# Scottish Mortgage Ord                     0.175274 -0.072753      -0.333
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc  0.534736 -0.026024   -0.077371
# WisdomTree Physical Gold GBP              0.217616  0.050198    0.045521
# iShares $ TIPS ETF USD Acc GBP            0.384915 -0.005765   -0.030064
#
#                                          six_month  ... yearly_skew  \
# BlackRock Ntrl Resources Gr & Inc D Acc    0.24209  ...     1.46509
# SLI UK Real Estt Accumulation Fdr P1Inc    0.05708  ...    0.030694
# Scottish Mortgage Ord                    -0.267301  ...    0.609489
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc -0.024029  ...   -0.378322
# WisdomTree Physical Gold GBP              0.077148  ...    0.037644
# iShares $ TIPS ETF USD Acc GBP            0.013212  ...     1.09331
#
#                                          yearly_kurt best_year worst_year  \
# BlackRock Ntrl Resources Gr & Inc D Acc       2.9028  0.597458  -0.202703
# SLI UK Real Estt Accumulation Fdr P1Inc    -0.807713  0.074916  -0.066961
# Scottish Mortgage Ord                       2.230755  1.096718  -0.462798
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc   -0.815762  0.293264  -0.071124
# WisdomTree Physical Gold GBP                0.903435  0.453779  -0.295959
# iShares $ TIPS ETF USD Acc GBP              2.080371  0.374725  -0.118149
#
#                                          avg_drawdown avg_drawdown_days  \
# BlackRock Ntrl Resources Gr & Inc D Acc     -0.053655        106.361111
# SLI UK Real Estt Accumulation Fdr P1Inc     -0.166824            2125.0
# Scottish Mortgage Ord                       -0.043638         44.845238
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc    -0.021924         22.392265
# WisdomTree Physical Gold GBP                  -0.0483         81.580645
# iShares $ TIPS ETF USD Acc GBP              -0.033637         77.405797
#
#                                          avg_up_month avg_down_month  \
# BlackRock Ntrl Resources Gr & Inc D Acc      0.041348      -0.038852
# SLI UK Real Estt Accumulation Fdr P1Inc       0.00456      -0.008501
# Scottish Mortgage Ord                        0.046858      -0.053684
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc     0.030557      -0.025913
# WisdomTree Physical Gold GBP                 0.041997      -0.037562
# iShares $ TIPS ETF USD Acc GBP               0.023868      -0.019391
#
#                                          win_year_perc twelve_month_win_perc
# BlackRock Ntrl Resources Gr & Inc D Acc       0.636364              0.537815
# SLI UK Real Estt Accumulation Fdr P1Inc       0.666667              0.491803
# Scottish Mortgage Ord                         0.772727              0.741176
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc      0.769231              0.915493
# WisdomTree Physical Gold GBP                       0.8              0.654321
# iShares $ TIPS ETF USD Acc GBP                    0.75              0.773256
#
# [6 rows x 46 columns]

# %%
ret
# Out:
# fund        BlackRock Ntrl Resources Gr & Inc D Acc  \
# Date
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
# 2000-01-06                                      NaN
# ...                                             ...
# 2022-02-21                                -0.011726
# 2022-02-22                                 0.003163
# 2022-02-23                                -0.008951
# 2022-02-24                                -0.011833
# 2022-02-25                                 0.018420
#
# fund        SLI UK Real Estt Accumulation Fdr P1Inc  Scottish Mortgage Ord  \
# Date
# 2000-01-02                                      NaN               0.000000
# 2000-01-03                                      NaN               0.000000
# 2000-01-04                                      NaN              -0.020790
# 2000-01-05                                      NaN              -0.018047
# 2000-01-06                                      NaN              -0.004324
# ...                                             ...                    ...
# 2022-02-21                                 0.000000              -0.045320
# 2022-02-22                                 0.000209               0.006192
# 2022-02-23                                -0.000209              -0.014564
# 2022-02-24                                 0.000000              -0.011865
# 2022-02-25                                 0.000209               0.053823
#
# fund        Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc  \
# Date
# 2000-01-02                                       NaN
# 2000-01-03                                       NaN
# 2000-01-04                                       NaN
# 2000-01-05                                       NaN
# 2000-01-06                                       NaN
# ...                                              ...
# 2022-02-21                                 -0.004437
# 2022-02-22                                 -0.008322
# 2022-02-23                                 -0.010992
# 2022-02-24                                  0.021365
# 2022-02-25                                  0.013528
#
# fund        WisdomTree Physical Gold GBP  iShares $ TIPS ETF USD Acc GBP
# Date
# 2000-01-02                           NaN                             NaN
# 2000-01-03                           NaN                             NaN
# 2000-01-04                           NaN                             NaN
# 2000-01-05                           NaN                             NaN
# 2000-01-06                           NaN                             NaN
# ...                                  ...                             ...
# 2022-02-21                      0.000000                        0.000000
# 2022-02-22                      0.003802                        0.002813
# 2022-02-23                      0.005151                        0.002397
# 2022-02-24                      0.024002                        0.023582
# 2022-02-25                     -0.023880                       -0.006689
#
# [8091 rows x 6 columns]

# %% [markdown]
# ### Diversification

# %%
beta_Co_Moments_table(ret, ret['Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc']).sort_values('BetaCoVariance')
# Out:
#                                           BetaCoVariance  BetaCoSkewness  \
# asset
# SLI UK Real Estt Accumulation Fdr P1Inc        -0.012579        0.086920
# WisdomTree Physical Gold GBP                    0.152447       -0.540678
# iShares $ TIPS ETF USD Acc GBP                  0.169364       -0.188837
# BlackRock Ntrl Resources Gr & Inc D Acc         0.552657        2.031597
# Scottish Mortgage Ord                           0.956736        0.699713
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc        1.000000        1.000000
#
#                                           BetaCoKurtosis
# asset
# SLI UK Real Estt Accumulation Fdr P1Inc        -0.007327
# WisdomTree Physical Gold GBP                    0.150806
# iShares $ TIPS ETF USD Acc GBP                  0.261390
# BlackRock Ntrl Resources Gr & Inc D Acc         0.833167
# Scottish Mortgage Ord                           0.796905
# Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc        1.000000

# %%
alpha_beta_table(ret, ret['Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc'], period = 'daily')
# Out:
#                                          alpha  alpha_bull  alpha_bear  beta  \
# asset
# BlackRock Ntrl Resources Gr & Inc D Acc  -0.93       -0.95       -0.78  0.47
# SLI UK Real Estt Accumulation Fdr P1Inc  -0.99       -0.99       -0.99 -0.01
# Scottish Mortgage Ord                    -0.16       -0.32       -0.40  0.96
# WisdomTree Physical Gold GBP             -0.99       -0.98       -1.00  0.15
# iShares $ TIPS ETF USD Acc GBP           -0.98       -0.98       -0.99  0.17
#
#                                          beta_bull  beta_bear
# asset
# BlackRock Ntrl Resources Gr & Inc D Acc       0.38       0.63
# SLI UK Real Estt Accumulation Fdr P1Inc      -0.02       0.00
# Scottish Mortgage Ord                         0.85       0.92
# WisdomTree Physical Gold GBP                  0.27       0.00
# iShares $ TIPS ETF USD Acc GBP                0.23       0.09

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20, 15)
#plt.style.use('fast')

df_plot.plot(subplots=True,
          layout=(5, 3),
          sharex=False,
          sharey=False,
         #colormap='viridis',
         fontsize=12,
         legend=True,
         linewidth=0.2);
plt.tight_layout();

# %%
ret = calculate_returns(df_plot)
ret = ret[ret.index>='2006-01-04']
### Adjust returns for Yields 
#ret['Royal London Sterl Extra Yld Bd A'] = ret['Royal London Sterl Extra Yld Bd A'] + ffn.core.deannualize(0.05, 1)
#ret['M&G Emerging Markets Bond GBP I Inc'] = ret['M&G Emerging Markets Bond GBP I Inc'] + + ffn.core.deannualize(0.05, 1)
eq_weights = equal_weight_portfolio(ret)
#eq_weights.port_naive = [0.10, 0.10, 0.05, 0.05, 0.05, 0.10, 0.20,0.15,0.10, 0.10]

# %%
eq_weights

# %%
pl_risk = risk_contributions(port_weights = eq_weights, 
                             returns = ret,
                             risk_measure = 'MV',
                             plot = True)
pl_risk

# %%
eq_weights = eq_weights.iloc[:,0].to_dict()
portfolio = qs.utils.make_index(ticker_weights = eq_weights, 
                                                period='max', 
                                                rebalance = None,
                                                returns=ret, 
                                                match_dates=False)
portfolio

# %%
ret = get_benchmark_porfolios()['All_Weather_Dalio'].dropna()

# %%
ret_assets = download_returns(['BRWM.L', '^GSPC' , 'IAU', 'TIP' ])

# %%
performance_overview(ret_assets)

# %%
pd.DataFrame(ret_assets)

# %%
ret = convert_returns_freq(pd.DataFrame(ret_assets), convert_to = 'monthly')

# %%
eq_weights = equal_weight_portfolio(ret_assets)
port_ret = calculate_portfolio_returns(ret_assets, eq_weights.index.to_list(), eq_weights.port_naive.to_list())
port_ret.head()

# %%
sum([0.07,0.55 ,0.08,0.30])

# %%
ret_assets = download_returns(['BRWM.L', '^GSPC' , 'IAU', 'TIP' ])
ret = pd.DataFrame(ret_assets).dropna()
ret = convert_returns_freq(ret, convert_to = 'monthly')
eq_weights = equal_weight_portfolio(ret)
ret = calculate_portfolio_returns(ret, eq_weights.index.to_list(), [0.07,0.55 ,0.08,0.30])
performance_overview(ret)

# %%
ret

# %%
ret_possible_path_cum = sim_paths(ret,
                                 # weight_period = ['2009-01-01', '2013-01-01'], 
                                  out_of_sample_start_date = '2020-01-01')

dist = prep_dist(ret_possible_path_cum)

plot_fan_chart(ret, dist, out_of_sample_date = '2020-01-01', 
               chart_title = 'Cumulative Returns (%)')

# %%
ret_assets = download_returns(['BRWM.L', '^GSPC' , 'IAU', 'TIP' ])
ret = pd.DataFrame(ret_assets).dropna()
ret = convert_returns_freq(ret, convert_to = 'monthly')
ret

# %%
alpha_beta_table(portfolio, ret['Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc'], rf= 0.02)

# %%
#qs.reports.full(df_compare_rebalance[1], df_compare_rebalance[0], rf=0)
#portfolio = portfolio.rename(columns={0:'close'})
qs.reports.full(portfolio, 'SPY', rf=0.02, periods_per_year=252)

# %%
#port_ret = ffn.core.deannualize(portfolio, 12)
port_ret = portfolio
port_ret.index = port_ret.index.tz_localize('utc')
port_ret

# %%
returns_benchmark = ret['Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc']
#returns_benchmark = ffn.core.deannualize(returns_benchmark, 12)
returns_benchmark

# %%
returns_benchmark.index = returns_benchmark.index.tz_localize('utc')
returns_benchmark

# %%
pf.create_returns_tear_sheet(port_ret, benchmark_rets=returns_benchmark,
                             live_start_date='2021-1-1', bootstrap = True, 
                             return_fig=False)

# %%
## Optimise portfolios

# %%
portfolios = make_standard_portfolios(ret.fillna(0), target_return=None, 
                             target_volatility=0.08, 
                             weight_min=0.02, weight_max = 0.4, 
                             rebalance = None)

# %%
portfolios

# %%
portf_series = portfolios[0]
port_weights = portfolios[1]

# %%
port_weights

# %%
port_weights[['port_target_vol']]

# %%
 port_ret = portfolios[0][['port_Targ_Vol']]

# %%
qs.reports.full(port_ret['port_Targ_Vol'], 'SPY', rf=0.02, periods_per_year= 252)

# %%
port_ret.index = port_ret.index.tz_localize('utc')
port_ret

# %%
pf.create_returns_tear_sheet(port_ret['port_Targ_Vol'], benchmark_rets=returns_benchmark,  
                             live_start_date='2021-1-1', bootstrap = True, 
                             return_fig=False)

# %%
ret_sp = download_returns(yahoo_tickers = ['SMT.L', 'DBC', '^GSPC'])
ret_sp = ret_sp[(ret_sp.index>='1990-01-01')]
ret_sp = ret_sp.dropna()

# %%
ret_sp = ret_sp.rolling(252).mean()

# %%
ret_sp.dropna()

# %%
ret_sp.index = ret_sp.index.tz_localize('utc')

# %%
#ret_sp['^GSPC']

pf.create_returns_tear_sheet(ret_sp['DBC'], benchmark_rets=ret_sp['^GSPC'],
                             live_start_date='2021-01-01', bootstrap = True, 
                             return_fig=False)
