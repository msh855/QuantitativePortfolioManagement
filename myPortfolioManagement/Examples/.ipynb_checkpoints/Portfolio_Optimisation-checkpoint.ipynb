# %% [markdown]
# ### myPortfolioManagement Package (Portfolio Optimisation)
#
#  - Routine to download data
#  - Routine to quickly see correlations ( linear, non-linear - at tails )
#  - Routine to quickly Generate HRP portfolio with a range of risk measure objectives, linkages and constraints

# %%
import warnings
warnings.filterwarnings('ignore')

# for interactive 
from itables import init_notebook_mode
init_notebook_mode(all_interactive = True)
import itables.options as opt
opt.maxBytes = 2**20
opt.maxColumns= 0

import pandas as pd 
#pd.options.display.float_format = '{:.2%}'.format

import numpy as np
from os import path 

import pyfolio as pf

import pypfopt
from pypfopt import expected_returns
from pypfopt import plotting
import ffn

import riskfolio as rp
from datetime import date, timedelta

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %cd /Users/safishajjouz/GitHub/QuantitativePortfolioManagement
# Out:
# /Users/safishajjouz/GitHub/QuantitativePortfolioManagement

# %%
from myequal_weight_portfolio
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/7g/gr9fl0cx43g5f42xf78n_str0000gn/T/ipykernel_60888/2073123372.py in <cell line: 3>()
#       1 from myPortfolioManagement.myData import *
#       2 from myPortfolioManagement.myPortfolioSelection import *
# ----> 3 from myPortfolioManagement.myPortfolioOptimisation import *
#
# ~/GitHub/QuantitativePortfolioManagement/myPortfolioManagement/myPortfolioOptimisation.py in <module>
#      22 from timebudget import timebudget  # to time functions
#      23 import itertools
# ---> 24 from myPortfolioManagement.myReturns import average_returns
#      25
#      26
#
# ~/GitHub/QuantitativePortfolioManagement/myPortfolioManagement/myReturns.py in <module>
#      15
#      16 import quantstats as qs
# ---> 17 from myPortfolioManagement.myData import download_stock_returns
#      18
#      19
#
# ImportError: cannot import name 'download_stock_returns' from 'myPortfolioManagement.myData' (/Users/safishajjouz/GitHub/QuantitativePortfolioManagement/myPortfolioManagement/myData.py)

# %%
# import list of funds 
mypath    = '/Users/safishajjouz/GitHub/QuantitativePortfolioManagement/myPortfolioManagement/Data'
file_name = "returns_sample.csv"
file_path_to_load = path.join(mypath, file_name)
ret = pd.read_csv(file_path_to_load)
ret['Date'] = pd.to_datetime(ret['Date'])
ret = ret.set_index('Date')
ret.head()
# Out:
#             ASI Global Inflation-Link Bd P1 Acc  Allianz Strategic Bond C Inc  \
# Date
# 2006-04-01                             0.000000                      0.003733
# 2006-05-01                             0.005277                      0.001793
# 2006-06-01                            -0.010499                      0.001326
# 2006-09-01                             0.009726                     -0.000265
# 2006-10-01                             0.000000                     -0.001258
#
#             Allianz Technology Trust Ord  \
# Date
# 2006-04-01                      0.006645
# 2006-05-01                     -0.003300
# 2006-06-01                      0.009934
# 2006-09-01                      0.005464
# 2006-10-01                      0.000000
#
#             Baillie Gifford Global Inc Growth B Acc  \
# Date
# 2006-04-01                                      NaN
# 2006-05-01                                      NaN
# 2006-06-01                                      NaN
# 2006-09-01                                      NaN
# 2006-10-01                                      NaN
#
#             BlackRock European Absolute Alpha D Acc  \
# Date
# 2006-04-01                                      NaN
# 2006-05-01                                      NaN
# 2006-06-01                                      NaN
# 2006-09-01                                      NaN
# 2006-10-01                                      NaN
#
#             BlackRock Throgmorton Trust Ord  BlackRock World Mining Trust Ord  \
# Date
# 2006-04-01                         0.016779                          0.012500
# 2006-05-01                         0.001650                         -0.006859
# 2006-06-01                         0.000000                          0.004144
# 2006-09-01                         0.003295                          0.010316
# 2006-10-01                        -0.001642                         -0.017018
#
#             Fidelity Asian Values Ord  Fidelity China Special Ord  \
# Date
# 2006-04-01                   0.031707                         NaN
# 2006-05-01                   0.007092                         NaN
# 2006-06-01                   0.000000                         NaN
# 2006-09-01                   0.007042                         NaN
# 2006-10-01                  -0.016317                         NaN
#
#             Fidelity Global Technology W-Acc-GBP  ...  \
# Date                                              ...
# 2006-04-01                              0.009346  ...
# 2006-05-01                              0.009259  ...
# 2006-06-01                              0.009174  ...
# 2006-09-01                              0.009091  ...
# 2006-10-01                              0.000000  ...
#
#             Trojan Fund X Accumulation  VT Argonaut Absolute Return R GBP Acc  \
# Date
# 2006-04-01                         NaN                                    NaN
# 2006-05-01                         NaN                                    NaN
# 2006-06-01                         NaN                                    NaN
# 2006-09-01                         NaN                                    NaN
# 2006-10-01                         NaN                                    NaN
#
#             Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc  \
# Date
# 2006-04-01                                       NaN
# 2006-05-01                                       NaN
# 2006-06-01                                       NaN
# 2006-09-01                                       NaN
# 2006-10-01                                       NaN
#
#             Vanguard Glb Bd Idx £ H Acc  WisdomTree Physical Gold GBP  \
# Date
# 2006-04-01                          NaN                           NaN
# 2006-05-01                          NaN                           NaN
# 2006-06-01                          NaN                           NaN
# 2006-09-01                          NaN                           NaN
# 2006-10-01                          NaN                           NaN
#
#             iShares Core S&P 500 ETF USD Acc GBP  \
# Date
# 2006-04-01                                   NaN
# 2006-05-01                                   NaN
# 2006-06-01                                   NaN
# 2006-09-01                                   NaN
# 2006-10-01                                   NaN
#
#             iShares Global Water ETF USD Dist GBP  \
# Date
# 2006-04-01                                    NaN
# 2006-05-01                                    NaN
# 2006-06-01                                    NaN
# 2006-09-01                                    NaN
# 2006-10-01                                    NaN
#
#             iShares S&P SmallCap 600 ETF USD Dist GBP  NASDAQ Composite  \
# Date
# 2006-04-01                                        NaN          0.008789
# 2006-05-01                                        NaN          0.005925
# 2006-06-01                                        NaN          0.012627
# 2006-09-01                                        NaN          0.005669
# 2006-10-01                                        NaN          0.000703
#
#              S&P 500
# Date
# 2006-04-01  0.003673
# 2006-05-01  0.000016
# 2006-06-01  0.009399
# 2006-09-01  0.003656
# 2006-10-01 -0.000357
#
# [5 rows x 45 columns]

# %%
## Portfolio Optimisation 

myassets = ['Scottish Mortgage Ord',                # Global Equity (focus on long-term) 
            'Invesco EQQQ NASDAQ-100 ETF GBP',      # Tech 
            'Rathbone Global Opportunities S Acc',  # Flex Global Cap 
            'Stewart Inv APAC Ldrs Sstby B GBP Acc', # Pacific Specialist 
            'BlackRock Throgmorton Trust Ord',       # UK small Cap 
            'HarbourVest Global Priv Equity Ord',    # Alternative 
            'Janus Henderson Mlt-Ast AbsRet I Acc']  # Absolute Alpha (proxy for JPM's fund due to missing data)

### Training Period 

training_start_date = '2018-01-01'
trainsing_end_date  = '2020-01-01'

ret_training = ret[myassets]
ret_training = ret_training[(ret_training.index>=training_start_date) & (ret_training.index<=trainsing_end_date)]
ret_training
# Out:
#             Scottish Mortgage Ord  Invesco EQQQ NASDAQ-100 ETF GBP  \
# Date
# 2018-02-01              -0.001336                         0.000941
# 2018-03-01               0.017841                         0.016023
# 2018-04-01               0.008764                         0.000757
# 2018-05-01               0.003475                         0.006639
# 2018-08-01               0.009524                         0.005176
# ...                           ...                              ...
# 2019-12-24              -0.000859                        -0.002212
# 2019-12-26               0.000000                         0.000000
# 2019-12-27               0.011178                        -0.001853
# 2019-12-30              -0.009354                        -0.012416
# 2019-12-31              -0.006009                        -0.004406
#
#             Rathbone Global Opportunities S Acc  \
# Date
# 2018-02-01                            -0.003845
# 2018-03-01                             0.006272
# 2018-04-01                             0.011890
# 2018-05-01                             0.005638
# 2018-08-01                             0.009518
# ...                                         ...
# 2019-12-24                             0.002685
# 2019-12-26                             0.000000
# 2019-12-27                            -0.001388
# 2019-12-30                            -0.003340
# 2019-12-31                            -0.008448
#
#             Stewart Inv APAC Ldrs Sstby B GBP Acc  \
# Date
# 2018-02-01                               0.000427
# 2018-03-01                               0.000697
# 2018-04-01                               0.006354
# 2018-05-01                               0.006497
# 2018-08-01                               0.004013
# ...                                           ...
# 2019-12-24                               0.001599
# 2019-12-26                               0.000000
# 2019-12-27                              -0.005338
# 2019-12-30                              -0.001258
# 2019-12-31                              -0.012122
#
#             BlackRock Throgmorton Trust Ord  \
# Date
# 2018-02-01                        -0.003145
# 2018-03-01                         0.011567
# 2018-04-01                         0.003119
# 2018-05-01                         0.004145
# 2018-08-01                         0.000000
# ...                                     ...
# 2019-12-24                         0.005857
# 2019-12-26                         0.000000
# 2019-12-27                        -0.002911
# 2019-12-30                         0.000000
# 2019-12-31                         0.004380
#
#             HarbourVest Global Priv Equity Ord  \
# Date
# 2018-02-01                           -0.012862
# 2018-03-01                            0.001629
# 2018-04-01                            0.008130
# 2018-05-01                           -0.003226
# 2018-08-01                            0.011327
# ...                                        ...
# 2019-12-24                           -0.001112
# 2019-12-26                            0.000000
# 2019-12-27                            0.007795
# 2019-12-30                           -0.004420
# 2019-12-31                           -0.002220
#
#             Janus Henderson Mlt-Ast AbsRet I Acc
# Date
# 2018-02-01                              0.001715
# 2018-03-01                              0.000000
# 2018-04-01                              0.002568
# 2018-05-01                              0.003416
# 2018-08-01                              0.000000
# ...                                          ...
# 2019-12-24                              0.000838
# 2019-12-26                              0.000000
# 2019-12-27                              0.001674
# 2019-12-30                             -0.000835
# 2019-12-31                              0.000000
#
# [503 rows x 7 columns]

# %%
### Naive Allocation 
df_naive = equal_weight_portfolio(ret_training, my_assets_col_name='fund')
df_naive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7g/gr9fl0cx43g5f42xf78n_str0000gn/T/ipykernel_60888/1902129100.py in <cell line: 2>()
#       1 ### Naive Allocation
# ----> 2 df_naive = equal_weight_portfolio(ret_training, my_assets_col_name='fund')
#       3 df_naive
#
# NameError: name 'equal_weight_portfolio' is not defined

# %%
df_inverse_vol = inverse_vol_portfolio(ret_training, my_assets_col_name='fund' , limit=0.4)
df_inverse_vol

# %%
### Inverse Volatility
df_inverse_vol.index = df_inverse_vol.index.set_names(['fund'] )
df_inverse_vol = df_inverse_vol.reset_index()
df_all_weights = df_inverse_vol.merge(df_naive, on = 'fund')
df_all_weights

# %%
### Risk Parity 
df_rp = generate_rp_portfolios(ret_training, risk_measure='MSV', limit = 0.4)

# %%
df_rp.index = df_rp.index.set_names(['fund'])
df_rp = df_rp.reset_index()

df_all_weights = df_all_weights.merge(df_rp, on = 'fund')
df_all_weights

# %% [markdown]
# ### De Prado's Hierarchical
#
# HERC and other extensions don;t work currently with constraints (To do: filter them out)

# %%
df_HRP_portfolios = generate_HRP_portfolios(returns_training = ret_training.dropna(), 
                            weight_max = 0.40,
                            weight_min = 0.05,
                            rf = 0.01)

# %%
df_HRP_portfolios.index = df_HRP_portfolios.index.set_names(['fund'])
df_HRP_portfolios = df_HRP_portfolios.reset_index()
df_all_weights = df_all_weights.merge(df_HRP_portfolios, on = 'fund')
df_all_weights

# %%
df_all_weights = df_all_weights.set_index('fund')

# %%
df_portfolio_returns = []
for col in df_all_weights.columns:
    temp =  culculate_portfolio_returns(ret, 
                                myassets_list = list(df_all_weights.index),
                                myweights_list= df_all_weights[col],
                                portfolio_name = col)
    df_portfolio_returns.append(temp)

df_portfolio_returns = pd.concat(df_portfolio_returns, axis = 1)

# %%
df_portfolio_returns

# %% [markdown]
# ### in-sample returns
#
# To do:
# - Train in the model in the full sample and leave out recent months / year to check out-of-sample
# - Check under different market regimes
# - Train the model and check it against "unseen" regime
# - Train the model between 2020-01 till 20-03-01 (reason is this period good proxy for condensing "100 years" of history ( tail risk due to pandemic, rise and fall of crash of tech stocks, rise of commodities, recession-recovery, rising inflation and yields, boom and bust of China etc -- note: missing QE tapering and interest rates shocks. Accommodate this with stress-testing checks. )
#
#
# df_all_weights = df_all_weights.set_index('fund')
# df_portfolio_returns = pd.DataFrame([])
# for portfolio_name in list(df_all_weights.columns):
#     temp = culculate_portfolio_returns(ret,
#                                        df_all_weights.index.to_list(),
#                                        df_all_weights[portfolio_name].to_list(),
#                                        portfolio_name = portfolio_name)
#     df_portfolio_returns = pd.concat([df_portfolio_returns, temp], axis=1)
#
# df_portfolio_returns

# %%
# check some basic perfomance stats for each asset 
price_index = ffn.core.to_price_index(df_portfolio_returns, start=100)
df_stats = ffn.core.GroupStats(price_index).stats
df_stats = df_stats.transpose().drop(['start', 'end', 'rf'], axis = 1)
df_stats

# %%
### Merge Portfolio returns 
ret_all = df_portfolio_returns.reset_index().merge(ret.reset_index(), on= 'Date')

# %%
ret_all = ret_all.set_index('Date')

# %%
price_index = ffn.core.to_price_index(ret_all, start=100)

# %%
price_index

# %%
df_all_prices = pd.melt(price_index.reset_index(), id_vars = 'Date',value_name = 'price', var_name = 'fund')

# %%
# choose benchmark
bench = ['Vanguard FTSE Dev Wld ex-UK Eq Idx £ Acc', 
         'iShares Core S&P 500 ETF USD Acc GBP',
        'Invesco EQQQ NASDAQ-100 ETF GBP'][2]


rolling_window     = 5
rolling_frequency  = 'Y'
my_assets_col_name = 'fund' 
my_date_col_name   = 'Date'
price_col_name = 'price'
benchmark_name = bench

df_reward_metrics = ranking_metrics(df = df_all_prices, 
                                   rolling_window = rolling_window, 
                                   rolling_frequency = rolling_frequency,
                                   my_assets_col_name = my_assets_col_name, 
                                   my_date_col_name = my_date_col_name,
                                   price_col_name = price_col_name,
                                   benchmark_name = benchmark_name)
df_reward_metrics

# %% [markdown]
# ### To Do list
#
#  - Integrate the Black-Litterman allocation
#  - Integrate the clustering process to filter out similar portfolios
#  - Build and integrate piplelines to automatically detect / suggest diversified portfolios on the available asset space
#  - Integrate the backtest process
#
# ### To do functionalities
#  - Extend to stochastic backtesting
#  - Calculate expected returns and expected volatilities through bootstrapping (simulations ) or Bayesian methods (e.g. incorporate the process for EM bond diversification)
#  - Stress Test Portfolios
#      - Robustness against macroeconomic shocks (e.g. Extend Blanchard's VAR paper that has the decomposition between demand and supply Shock)
#      - Robustness against monetary shocks (e.g. Use Bernake's paper FVAR model )
#      - Robustness against Fiscal Shocks (e.g. Mumtaz's paper , monetary-fiscal interaction VAR models might also do)
#  - Model correlations of assets in the portfolio (e.g. through Dynamic factor models -- collect data to explain factors)
#  - Calculate beta's and extend to Bayesian method the standard CAPM (to get a distribution of possible beta's / alphas)
#  - Process that produce a scorecard and provide the overall signal
