# %% [markdown]
# ### Steps
#
# 1. Install Rstudion in Anaconda and in the enviroment you are working
# 2. !conda install -y PyHamcrest
# 3. !conda update -c rdonnellyr -c main --all

# %%
import rpy2

from rpy2.robjects import pandas2ri, packages
pandas2ri.activate()
#stats = packages.importr('stats')
#zoo = packages.importr('zoo')
#PerformanceAnalytics = packages.importr('PerformanceAnalytics')

# %%
# %load_ext rpy2.ipython

# %%
names_to_install
