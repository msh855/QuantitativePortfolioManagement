# %% [markdown]
# ### 1. Clustering samples

# %% [markdown]
# Application of a simple Machine learning approach for clustering [link](https://wire.insiderfinance.io/inflation-regimes-what-basic-clustering-methods-are-saying-5eec29bf58bf). Please excuse the funny tone of the article as the audience here is quite different.

# %% [markdown]
# ### 2. Data Engineering

# %% [markdown]
# In this public article I illustrate the use of Ray in python as a scalable solution to download stock prices from free sources.
#
#
# https://medium.com/@shajjouz/how-to-download-stock-prices-faster-using-ray-25d15bd2642e
